# %% [markdown]
# # <center>SQL Analysis On B2B Sales Data</center>

# %% [markdown]
# ## Set Up

# %% [markdown]
# Import necessary libraries

# %%
# importing pandas as pd just in case it is needed
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# Load SQL extenstion

# %%
# %load_ext sql

# %% [markdown]
# Establish conncection to MySQL Database

# %%
# %sql mysql://USERNAME:PASSWORD@HOST/DATABASE

# %% [markdown]
# ## Part 1: Exploratory Analysis

# %% [markdown]
# a). Quite a few accounts have NULL in the PartnerId column so it is worth it to take a closer look to see exactly how many null values are there in the PartnerId column and what these NULL values mean.

# %%
# %%sql
# SELECT COUNT(*)
# FROM Accounts
# WHERE PartnerId IS NULL;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(3035,)]

# %%
# %%sql
# SELECT
#     AccountName,
#     PartnerId
# FROM Accounts
# WHERE PartnerId IS NULL;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 3035 rows affected.
# [('Blue Origin', None),
#  ('Agilent Technologies, Inc', None),
#  (' Project Systems Corporation', None),
#  ('Alibaba Group', None),
#  ('Canon Business Professional Services (OEM)', None),
#  ('CloudDOCX (OEM)', None),
#  ('Crunch Technologies Corporation', None),
#  ('Curiato, Inc. (OEM)', None),
#  ('eLeadCRM (OEM)', None),
#  ('Elixir Technologies Corporation', None),
#  ('EZOPS Inc (OEM)', None),
#  ('Flatirons Solutions Inc (OEM)', None),
#  ('IPEC Project Systems Sdn Bhd', None),
#  ('Iron Mountain, Inc', None),
#  ('Kronos Incorporated', None),
#  ('Link Technology Group', None),
#  ('MoxiWorks', None),
#  ('Mutual Concept Computer Group Inc. (OEM)', None),
#  ('National Association of Insurance Commissioners', None),
#  ('National Sports Academy', None),
#  ('New Machine Computer Group Inc.', None),
#  ('Omnicon Group (OEM)', None),
#  ('Orbis Technologies, Inc.', None),
#  ('RioSoft (OEM)', None),
#  ('Sapiens Americas', None),
#  ('Thomson Reuters', None),
#  ('Toppan Merrill', None),
#  ('West Coast Electric Corporation', None),
#  ('Xerox DocuShare (OEM)', None),
#  ('Yokogawa Electric Corporation', None),
#  ('Accurate Background', None),
#  ('Lexipol LLC', None),
#  ('Los Angeles Unified School District', None),
#  ('Michaels Stores, Inc.', None),
#  ('NextSphere Technologies', None),
#  ('SAE International', None),
#  ('Social Finance, Inc.', None),
#  ('SOUTHWEST BUSINESS CORPORATION', None),
#  ('UCLA', None),
#  ('University of California, Agriculture and Natural Resources', None),
#  ('4DX', None),
#  ('Accenture China', None),
#  ('ACCENTURE PTE LTD', None),
#  ('AIA Hong Kong', None),
#  ('Allianz SE Singapore Branch', None),
#  ('Aqsacom', None),
#  ('Beijing Shouhuan Cultural Tourism Investment Co., Ltd.', None),
#  ('Bureau Veritas HK Ltd.', None),
#  ('Central Bank', None),
#  ('Cognizant Technology Solutions Hong Kong Ltd', None),
#  ('Department of Parliamentary Services', None),
#  ('Eclipx Group Limited', None),
#  ('Enterprise Singapore', None),
#  ('GE Digital China', None),
#  ('GENIX VENTURES PTY LTD', None),
#  ('i3esolutions, inc', None),
#  ('Icare NSW', None),
#  ('James Cook University Singapore', None),
#  ('Li & Fung (Trading) Limited', None),
#  ('LINK MARKET SERVICES GROUP PTY LIMITED', None),
#  ('MINTER ELLISON LAWYERS', None),
#  ('NATIONAL AUSTRALIA BANK LIMITED', None),
#  ('NCSI', None),
#  ('News Pty Limited', None),
#  ('NSW DEPARTMENT OF POLICE AND JUSTICE', None),
#  ('Prudential Investment Company of Australia', None),
#  ('SIEBRENET Inc.', None),
#  ('Standard Chartered Bank', None),
#  ('TABCORP HOLDINGS LIMITED', None),
#  ('TELSTRA HOLDINGS PTY LTD', None),
#  ('UFINITY GROUP LIMITED', None),
#  ('Vietnam Electricity', None),
#  ('Welab Holdings', None),
#  ('Bice Vida Compañía De Seguros', None),
#  ('Colmena Seguros', None),
#  ('Pentafon', None),
#  ('Procargo Port', None),
#  ('SOGE Bank', None),
#  ('St. Lucia - Government of Information Technology', None),
#  ('ZURICH SANTANDER - Uruguay', None),
#  ('Boeing DMS', None),
#  ('California DOJ', None),
#  ('CoreLogic Inc, Solutions, LLC', None),
#  ('Google Inc', None),
#  ('Intel Corporation', None),
#  ('Oregon Department of Human Services', None),
#  ('Robert Half International Inc', None),
#  ('TOYOTA MOTOR CREDIT CORPORATION', None),
#  ('Wells Fargo & Company AZ', None),
#  ('Wells Fargo Bank, N.A.', None),
#  ('Boost Insurance', None),
#  ('Quality Steel Corporation', None),
#  ('ScienceLogic', None),
#  ('Spruce Technology', None),
#  ('SoftBank', None),
#  ('Citigroup', None),
#  ('Facebook', None),
#  ('Intel', None),
#  ('OurCrowd', None),
#  ('Pindrop', None),
#  ('Stripe', None),
#  ('The Honest Company', None),
#  ('Jumio', None),
#  ('Airwallex', None),
#  ('Groww', None),
#  ('Redis Labs', None),
#  ('Hopper', None),
#  ('Ironclad', None),
#  ('Cyble', None),
#  ('DocuSign', None),
#  ('Silver Lake', None),
#  ('Box', None),
#  ('CrowdStrike', None),
#  ('Outreach', None),
#  ('Unacademy', None),
#  ('Verkada', None),
#  ('Seedrs', None),
#  ('Skydio', None),
#  ('GupShup', None),
#  ('Cowbell Cyber', None),
#  ('SecurityScorecard', None),
#  ('Draper Esprit', None),
#  ('Trax', None),
#  ('Dropbox', None),
#  ('Airtable', None),
#  ('Bitwise Industries', None),
#  ('SumUp', None),
#  ('BNY Mellon', None),
#  ('eToro', None),
#  ('Northvolt', None),
#  ('Dataminr', None),
#  ('Yotpo', None),
#  ('DST Global', None),
#  ('Uber', None),
#  ('Starling Bank', None),
#  ('Binance', None),
#  ('Peloton', None),
#  ('MessageBird', None),
#  ('Sendbird', None),
#  ('Uniphore', None),
#  ('Feedzai', None),
#  ('UnitedMasters', None),
#  ('Eat Just', None),
#  ('Invitae', None),
#  ('Lattice', None),
#  ('Trustpilot', None),
#  ('Acorns', None),
#  ('Foxconn Technology Group', None),
#  ('Binance Labs', None),
#  ('Kavak', None),
#  ('Olo', None),
#  ('Greensill Capital', None),
#  ('Neuralink', None),
#  ('GitLab', None),
#  ('Sanofi', None),
#  ('Affirm', None),
#  ('Nearpod', None),
#  ('ChargePoint', None),
#  ('Ubisoft', None),
#  ('WhiteSource', None),
#  ('Komodo Health', None),
#  ('Polkadot', None),
#  ('Impossible Foods', None),
#  ('AngelList', None),
#  ('Cloudflare', None),
#  ('Bristol-Myers Squibb', None),
#  ('Republic', None),
#  ('Techstars', None),
#  ('Inscripta', None),
#  ('Niantic', None),
#  ('Ada', None),
#  ('SoundCloud', None),
#  ('Tesla', None),
#  ('Gorillas', None),
#  ('Hulu', None),
#  ('Axonius', None),
#  ('Hippo Insurance', None),
#  ('PatSnap', None),
#  ('Snap', None),
#  ('Flutterwave', None),
#  ('Icertis', None),
#  ('MasterClass', None),
#  ('Forethought', None),
#  ('QuantumScape', None),
#  ('Lime', None),
#  ('Promise', None),
#  ('Oculus', None),
#  ('Sonos', None),
#  ('Innovaccer', None),
#  ('Evidation Health', None),
#  ('Poshmark', None),
#  ('Carta', None),
#  ('C3 AI', None),
#  ('Tinder', None),
#  ('Ramp', None),
#  ('Monzo', None),
#  ('Avant', None),
#  ('Xero', None),
#  ('KnowBe4', None),
#  ('Notarize', None),
#  ('Fanatics', None),
#  ('Automation Anywhere', None),
#  ('Tomorrow.io', None),
#  ('Chord', None),
#  ('Chainlink', None),
#  ('Hinge Health', None),
#  ('Nubank', None),
#  ('Wise', None),
#  ('Camunda', None),
#  ('Ajaib', None),
#  ('Zoom', None),
#  ('Traveloka', None),
#  ('Mayo Clinic', None),
#  ('BP', None),
#  ('Google', None),
#  ('HashiCorp', None),
#  ('Career Karma', None),
#  ('Urban Company', None),
#  ('Rapid7', None),
#  ('MainStreet', None),
#  ('Aclima', None),
#  ('NuORDER', None),
#  ('Teladoc', None),
#  ('Encantos', None),
#  ('Klarna', None),
#  ('Trust Stamp', None),
#  ('Zscaler', None),
#  ('Lookout', None),
#  ('Razorpay', None),
#  ('Checkout.com', None),
#  ('Blackberry', None),
#  ('PhonePe', None),
#  ('Segment', None),
#  ('Euler Motors', None),
#  ('Striim', None),
#  ('Glassdoor', None),
#  ('Voyage', None),
#  ('OPSWAT', None),
#  ('Socure', None),
#  ('Streamlit', None),
#  ('Savage X Fenty', None),
#  ('Staffbase', None),
#  ('Vuzix', None),
#  ('Rupeek', None),
#  ('On Deck', None),
#  ('Roche', None),
#  ('Jobandtalent', None),
#  ('Mogo', None),
#  ('Nordstrom', None),
#  ('Eight Sleep', None),
#  ('Axis Bank', None),
#  ('BRYTER', None),
#  ('OneWeb', None),
#  ('Paxos', None),
#  ('Matterport', None),
#  ('Allbirds', None),
#  ('SEMrush', None),
#  ('Bank of America', None),
#  ('Pendo', None),
#  ('Xiaomi', None),
#  ('FalconX', None),
#  ('Upwork', None),
#  ('Bevy', None),
#  ('Shine', None),
#  ('Big Hit Entertainment', None),
#  ('Envestnet', None),
#  ('BrightInsight', None),
#  ('Dream11', None),
#  ('Railsbank', None),
#  ('Lendingkart', None),
#  ('AKASA', None),
#  ('Nextdoor', None),
#  ('Chingari', None),
#  ('MercadoLibre', None),
#  ('Census', None),
#  ('Arrival', None),
#  ('Perpule', None),
#  ('Grubhub', None),
#  ('Appier', None),
#  ('Skillz', None),
#  ('Intercom', None),
#  ('Ginger', None),
#  ('G2', None),
#  ('VectivBio', None),
#  ('Meniga', None),
#  ('Sentry', None),
#  ('Talkspace', None),
#  ('Kroger', None),
#  ('Plug Power', None),
#  ('BT', None),
#  ('Insitro', None),
#  ('T. Rowe Price', None),
#  ('NextAI', None),
#  ('Tasktop', None),
#  ('Reputation.com', None),
#  ('Meesho', None),
#  ('GoCardless', None),
#  ('Eightfold', None),
#  ('Doma', None),
#  ('Prosimo.io', None),
#  ('Firefly Health', None),
#  ('Fivetran', None),
#  ('Crossover Health', None),
#  ('Vroom', None),
#  ('Holler', None),
#  ('Meltwater', None),
#  ('Infarm', None),
#  ('ConsenSys', None),
#  ('Open Co (Brazil)', None),
#  ('The Walt Disney Company', None),
#  ('Udacity', None),
#  ('Adani Green Energy', None),
#  ('Bayer', None),
#  ('H.I.G. Capital', None),
#  ('Cloud Elements', None),
#  ('Incredibuild', None),
#  ('Couchbase', None),
#  ('NerdWallet', None),
#  ('OutSystems', None),
#  ('BuzzFeed', None),
#  ('Microsoft', None),
#  ('Fastly', None),
#  ('Algorand', None),
#  ('Nutanix', None),
#  ('Recorded Future', None),
#  ('Manual', None),
#  ('Babylon Health', None),
#  ('Pluralsight', None),
#  ('AppliedVR', None),
#  ('Cleveland Clinic', None),
#  ('Evolv Technology', None),
#  ('Braze', None),
#  ('Lob', None),
#  ('Dish Network', None),
#  ('Gig Wage', None),
#  ('Strava', None),
#  ('UiPath', None),
#  ('Northern Arc', None),
#  ('Mambu', None),
#  ('10X Genomics', None),
#  ('YourStory', None),
#  ('Comet.ml', None),
#  ('Public.com', None),
#  ('Lukka', None),
#  ('Vimeo', None),
#  ('chiliZ', None),
#  ('Valo Health', None),
#  ('Workday', None),
#  ('Centrical', None),
#  ('Living Security', None),
#  ('Flexport', None),
#  ('Bakkt', None),
#  ('Roblox', None),
#  ('SuperRare', None),
#  ('MaC Venture Capital', None),
#  ('CLEAR', None),
#  ('Reliance Jio', None),
#  ('Offerpad', None),
#  ('Imperfect Foods', None),
#  ('Pandora', None),
#  ('Optibus', None),
#  ('MoviePass', None),
#  ('BlueVine', None),
#  ('Zalando', None),
#  ('Bartesian', None),
#  ('Productsup', None),
#  ('Mixpanel', None),
#  ('Dash Living', None),
#  ('Business Insider', None),
#  ('Arcadia', None),
#  ('Info Edge', None),
#  ('Lending Club', None),
#  ('Unsplash', None),
#  ('Scribe Therapeutics', None),
#  ('Carvana', None),
#  ('Broadridge', None),
#  ('Cora', None),
#  ('Cabify', None),
#  ('Amwell', None),
#  ('Side', None),
#  ('HSBC', None),
#  ('Memfault', None),
#  ('Contentsquare', None),
#  ('Zipline', None),
#  ('Vectra', None),
#  ('Cockroach Labs', None),
#  ('TigerGraph', None),
#  ('Rightway Healthcare', None),
#  ('Health IQ', None),
#  ('Play Shifu', None),
#  ('Kakao Corp', None),
#  ('Inshorts', None),
#  ('Netskope', None),
#  ('CurlMix', None),
#  ('Podium', None),
#  ('Omada Health', None),
#  ('Swiggy', None),
#  ('Humanigen', None),
#  ('Zwift', None),
#  ('RingCentral', None),
#  ('FarEye', None),
#  ('IndusInd Bank', None),
#  ('Via', None),
#  ('MyHeritage', None),
#  ('Coupang', None),
#  ('Tackle.io', None),
#  ('Telefonica', None),
#  ('Nexo', None),
#  ('Future Planet Capital', None),
#  ('Xendit', None),
#  ('Gumroad', None),
#  ('Neo4j', None),
#  ('Viz', None),
#  ('Penta', None),
#  ('Highspot', None),
#  ('Applitools', None),
#  ('ZEDEDA', None),
#  ('View', None),
#  ('Investcorp', None),
#  ('Apna', None),
#  ('Drip Capital', None),
#  ('Carbon Health', None),
#  ('Peakon', None),
#  ('Careem', None),
#  ('Somatus', None),
#  ('Blueshift', None),
#  ('Zapier', None),
#  ('Wave', None),
#  ('TryNow', None),
#  ('Morphisec', None),
#  ('AnyRoad', None),
#  ('Thumbtack', None),
#  ('Evernote', None),
#  ('Strive Health', None),
#  ('Twist Bioscience', None),
#  ('Stream', None),
#  ('Casper', None),
#  ('Credit Karma', None),
#  ('Wealthsimple', None),
#  ('Patreon', None),
#  ('Sportradar', None),
#  ('VTS', None),
#  ('Mighty Buildings', None),
#  ('Bionaut Labs', None),
#  ('Superhuman', None),
#  ('Zocdoc', None),
#  ('Bombay Shaving Company', None),
#  ('Evisort', None),
#  ('Seismic', None),
#  ('Webflow', None),
#  ('Domo', None),
#  ('Wefarm', None),
#  ('Dapper Labs', None),
#  ('Workato', None),
#  ('Afterpay', None),
#  ('Pantera Capital', None),
#  ('Armorblox', None),
#  ('Capdesk', None),
#  ('Pine Labs', None),
#  ('OZY Media', None),
#  ('Algolia', None),
#  ('Mayvenn', None),
#  ('Stash', None),
#  ('Snapcommerce', None),
#  ('airSlate', None),
#  ('Remitly', None),
#  ('Xpeng Motors', None),
#  ('Reef Finance', None),
#  ('Exscientia', None),
#  ('Petco', None),
#  ('Allianz', None),
#  ('REEF Technology', None),
#  ('Blavity, Inc.', None),
#  ('SmileDirectClub', None),
#  ('Trafigura', None),
#  ('SingleStore', None),
#  ('Zeni', None),
#  ('Farmers Business Network', None),
#  ('Barclays', None),
#  ('Talkdesk', None),
#  ('Garage Capital', None),
#  ('Ionis Pharmaceuticals', None),
#  ('Ecom Express', None),
#  ('MPB', None),
#  ('Puppet', None),
#  ('Codat', None),
#  ('Masai School', None),
#  ('Sberbank', None),
#  ('Cazoo', None),
#  ('Aspiration', None),
#  ('Carousell', None),
#  ('Klaviyo', None),
#  ('General Assembly', None),
#  ('Wellcome Trust', None),
#  ('BitPay', None),
#  ('Dremio', None),
#  ('Idelic', None),
#  ('Upstox', None),
#  ('Mask Network', None),
#  ('Bowery Farming', None),
#  ('KeepTruckin', None),
#  ('Care.com', None),
#  ('GlaxoSmithKline', None),
#  ('Fundbox', None),
#  ('Metromile', None),
#  ('3DLOOK', None),
#  ('AvidXchange', None),
#  ('Gyroscope Therapeutics', None),
#  ('UpGrad', None),
#  ('Olive', None),
#  ('Augmedics', None),
#  ('Infor', None),
#  ('Edmunds', None),
#  ('Eventbrite', None),
#  ('appfire', None),
#  ('Magic', None),
#  ('Weibo', None),
#  ('Alyce', None),
#  ('Fungible', None),
#  ('Benchling', None),
#  ('MyGlamm', None),
#  ('Vend', None),
#  ('Mapbox', None),
#  ('HYCU', None),
#  ('Emotive', None),
#  ('Zumper', None),
#  ('DHL', None),
#  ('Turtlemint', None),
#  ('H2O.ai', None),
#  ('Arcus', None),
#  ('Dialpad', None),
#  ('Alt', None),
#  ('Gojek', None),
#  ('Splice', None),
#  ('CERE Network', None),
#  ('Cresco Labs', None),
#  ('TAL Education Group', None),
#  ('MuleSoft', None),
#  ('Kaiser Permanente', None),
#  ('Pitstop', None),
#  ('iwoca', None),
#  ('SaltPay', None),
#  ('Tetrate', None),
#  ('AppDirect', None),
#  ('Theta Labs', None),
#  ('Pair Eyewear', None),
#  ('Pony.ai', None),
#  ('Deel', None),
#  ('Instacart', None),
#  ('Kaltura', None),
#  ('Glooko', None),
#  ('Aircall', None),
#  ('Romeo Power', None),
#  ('CasperLabs', None),
#  ('CleanSpark', None),
#  ('Partake Foods', None),
#  ('Creatio', None),
#  ('Nimble Robotics', None),
#  ('Talend', None),
#  ('Ideanomics', None),
#  ('Thrive Market', None),
#  ('CNH Industrial', None),
#  ('Casavo', None),
#  ('Eliem Therapeutics', None),
#  ('Saks Fifth Avenue', None),
#  ('Cylera', None),
#  ('Gitpod', None),
#  ('SurveyMonkey', None),
#  ('AU Small Finance Bank', None),
#  ('Doctor On Demand', None),
#  ('Rohlik', None),
#  ('River Financial', None),
#  ('Root Insurance', None),
#  ('Momenta', None),
#  ('Toppr', None),
#  ('Wallapop', None),
#  ('AbSci', None),
#  ('Skeleton Technologies', None),
#  ('Lend Street Financial', None),
#  ('Epidemic Sound', None),
#  ('Skyscanner', None),
#  ('Menlo Security', None),
#  ('PAYFAZZ', None),
#  ('Sisense', None),
#  ('Pantheon', None),
#  ('Memic Innovative Surgery', None),
#  ('Just Eat Takeaway', None),
#  ('CareAcademy', None),
#  ('Cognizant', None),
#  ('AbCellera Biologics', None),
#  ('Capsule', None),
#  ('Auditoria.AI', None),
#  ('Zignal Labs', None),
#  ('Kodak', None),
#  ('Enbridge', None),
#  ('Nuvia', None),
#  ('Canva', None),
#  ('Mercury Financial', None),
#  ('ShareChat', None),
#  ('Nykaa', None),
#  ('Berkshire Hathaway', None),
#  ('PandaDoc', None),
#  ('Monarch Tractor', None),
#  ('xMatters', None),
#  ('AntWak', None),
#  ('IndiaMART', None),
#  ('Qualia', None),
#  ('Biohaven Pharmaceutical', None),
#  ('Omega Therapeutics', None),
#  ('FORT Robotics', None),
#  ('Unioncrate', None),
#  ('Mirakl', None),
#  ('Innoviz Technologies', None),
#  ('Blippar', None),
#  ('Skycatch', None),
#  ('TransUnion', None),
#  ('Revolut', None),
#  ('Markforged', None),
#  ('OfferUp', None),
#  ('ClassPass', None),
#  ('Freshly', None),
#  ('PureStake', None),
#  ('Landit', None),
#  ('Pyxis Oncology', None),
#  ('Oda', None),
#  ('Sarcos Robotics', None),
#  ('Alloy Therapeutics', None),
#  ('iHeartMedia', None),
#  ('IRI', None),
#  ('Avanti Financial Group', None),
#  ('Trulioo', None),
#  ('comScore', None),
#  ('Honor', None),
#  ('Greenbits', None),
#  ('Nuvolo', None),
#  ('PAR Technology', None),
#  ('ActionIQ', None),
#  ('Ecovative Design', None),
#  ('Fluid Truck', None),
#  ('OpenLattice', None),
#  ('UST', None),
#  ('Starburst Data', None),
#  ('goTenna', None),
#  ('Vacasa', None),
#  ('Good Catch', None),
#  ('Collective Health', None),
#  ('ForgeRock', None),
#  ('Velocity Global', None),
#  ('Imperva', None),
#  ('Kraken', None),
#  ('Loggi', None),
#  ('Tylko', None),
#  ('Fiverr.com', None),
#  ('Instil Bio', None),
#  ('Fuel50', None),
#  ('Second Closet', None),
#  ('Creandum', None),
#  ('Foursquare', None),
#  ('ASAPP', None),
#  ('BrewDog', None),
#  ('Lyft', None),
#  ('project44', None),
#  ('Porter', None),
#  ('Sundial Growers', None),
#  ('Pfizer', None),
#  ('Signet Jewelers', None),
#  ('Quantum Metric', None),
#  ('MeaTech', None),
#  ('BetterCloud', None),
#  ('BYJU’S', None),
#  ('Zoomin Software', None),
#  ('Blue Apron', None),
#  ('Charter Communications', None),
#  ('NYMBUS', None),
#  ('Armis Security', None),
#  ('Clarify Health Solutions', None),
#  ('Gate.io', None),
#  ('Illumio', None),
#  ('Varo Money', None),
#  ('Convoy', None),
#  ('Instagram', None),
#  ('Ellevest', None),
#  ('Vinted', None),
#  ('Storytel', None),
#  ('MoEngage', None),
#  ('Artsy', None),
#  ('OwnBackup', None),
#  ('Blue Dot', None),
#  ('Lightyear', None),
#  ('Zuora', None),
#  ('Root AI', None),
#  ('SteadyMD', None),
#  ('LinkAja', None),
#  ('WeLab', None),
#  ('J2 Global', None),
#  ('Fetch.AI', None),
#  ('Elsa', None),
#  ('Enjoy', None),
#  ('Practo', None),
#  ('Guesty', None),
#  ('JP Morgan Chase', None),
#  ('Sweetgreen', None),
#  ('BrightPlan', None),
#  ('Checkr', None),
#  ('upSWOT', None),
#  ('Fondeadora', None),
#  ('Chargebee', None),
#  ('Aakash Educational Services', None),
#  ('Deezer', None),
#  ('DeHaat', None),
#  ('Gro', None),
#  ('Claroty', None),
#  ('Earnin', None),
#  ('Charles River Laboratories International', None),
#  ('Veriff', None),
#  ('Shadow', None),
#  ('WinZO', None),
#  ('Grayscale Bitcoin Trust', None),
#  ('Otonomo', None),
#  ('PhoreMost', None),
#  ('ESO', None),
#  ('Leap Finance', None),
#  ('MobiTV', None),
#  ('Point', None),
#  ('Stack Overflow', None),
#  ('MK Decision', None),
#  ('mfine', None),
#  ('Plenty', None),
#  ('Dave', None),
#  ('GloveBox', None),
#  ('Relativity', None),
#  ('MakeMyTrip.com', None),
#  ('Fiveable', None),
#  ('FireEye', None),
#  ('Live Nation Entertainment', None),
#  ('JD.com', None),
#  ('Zymergen', None),
#  ('WhatsApp', None),
#  ('Axiom Space', None),
#  ('Lyell Immunopharma', None),
#  ('Nuvei', None),
#  ('Taboola', None),
#  ('Incode Technologies', None),
#  ('CircleCI', None),
#  ('HealthHero', None),
#  ('Elastic', None),
#  ('boAt', None),
#  ('Solid Biosciences', None),
#  ('VSCO', None),
#  ('Alpian', None),
#  ('GrubMarket', None),
#  ('Pathlight', None),
#  ('Nikola Motor Company', None),
#  ('ZestMoney', None),
#  ('Retool', None),
#  ('Jamf', None),
#  ('Scandit', None),
#  ('Cheese', None),
#  ('SellerX', None),
#  ('AYR Wellness', None),
#  ('First Boulevard', None),
#  ('Pico Interactive', None),
#  ('Brainly', None),
#  ('The Boring Company', None),
#  ('Super League Gaming', None),
#  ('CAMPFIRE', None),
#  ('Oxford Nanopore Technologies', None),
#  ('Boom Supersonic', None),
#  ('Sezzle', None),
#  ('Porsche', None),
#  ('People.ai', None),
#  ('SchoolHouse', None),
#  ('iboss', None),
#  ('Eden Health', None),
#  ('Hi Marley', None),
#  ('Entrada Therapeutics', None),
#  ('Landing', None),
#  ('Onapsis', None),
#  ('SunPower', None),
#  ('ComplyAdvantage', None),
#  ('75F', None),
#  ('Miso Robotics', None),
#  ('Dollar Shave Club', None),
#  ('Jopwell', None),
#  ('Rocksbox', None),
#  ('Devoted Health', None),
#  ('The Carlyle Group', None),
#  ('Owlet Baby Care', None),
#  ('MDLIVE', None),
#  ('Propel(X)', None),
#  ('Nurx', None),
#  ('Tealium', None),
#  ('GroundTruth', None),
#  ('Electric', None),
#  ('Sysdig', None),
#  ('Scentbird', None),
#  ('Inflammatix', None),
#  ('Shift', None),
#  ('Moglix', None),
#  ('Medisafe', None),
#  ('Afiniti', None),
#  ('Kaseya', None),
#  ('BridgeBio', None),
#  ('Pendulum Therapeutics', None),
#  ('emocha Health', None),
#  ('Bloomberg', None),
#  ('Pipedrive', None),
#  ('Fetcher', None),
#  ('Cobalt', None),
#  ('Flex Logix Technologies', None),
#  ('Away', None),
#  ('1mg', None),
#  ('MyMoneyMantra', None),
#  ('Duolingo', None),
#  ('DXY', None),
#  ('Decentraland', None),
#  ('AmerisourceBergen', None),
#  ('StackShare', None),
#  ('TELUS', None),
#  ('Madison Reed', None),
#  ('DFINITY', None),
#  ('Wirecard', None),
#  ('Ethereum Foundation', None),
#  ('Centro', None),
#  ('Zenoti', None),
#  ('Macquarie Group', None),
#  ('Mented Cosmetics', None),
#  ('Earnix', None),
#  ('FutureFuel.io', None),
#  ('Casted', None),
#  ('Planet', None),
#  ('Agora.io', None),
#  ('ULTRA', None),
#  ('OmniSci', None),
#  ('Ankr', None),
#  ('Hudl', None),
#  ('Second Sight', None),
#  ('Abacum', None),
#  ('Halodoc', None),
#  ('CarDekho', None),
#  ('Arix Bioscience', None),
#  ('Yext', None),
#  ('QuintoAndar', None),
#  ('Didi', None),
#  ('Price.com', None),
#  ('Bitdefender', None),
#  ('Olympus', None),
#  ('Genesis Global', None),
#  ('Foxtrot', None),
#  ('Contentful', None),
#  ('Caribu', None),
#  ('Schneider Electric', None),
#  ('EnrichHER', None),
#  ('Yieldstreet', None),
#  ('Copper', None),
#  ('Rapyd', None),
#  ('VerSe Innovation', None),
#  ('Clio', None),
#  ('Design Therapeutics', None),
#  ('AptDeco', None),
#  ('Invstr', None),
#  ('Smartsheet', None),
#  ('Bizzabo', None),
#  ('Personio', None),
#  ('SambaNova Systems', None),
#  ('Samsung Electronics', None),
#  ('Lazada Group', None),
#  ('Ollie', None),
#  ('MeliBio', None),
#  ('Rhino', None),
#  ('Splitit', None),
#  ('ByteDance', None),
#  ('CloudTrucks', None),
#  ('Dija', None),
#  ('Fishbrain', None),
#  ('Truvian Sciences', None),
#  ('Amazon Web Services', None),
#  ('Whereby', None),
#  ('FinanZero', None),
#  ('Degreed', None),
#  ('Easebuzz', None),
#  ('Q2ebanking', None),
#  ('Congenica', None),
#  ('Planday', None),
#  ('Iflytek', None),
#  ('Avalara', None),
#  ('Flatiron Health', None),
#  ('Slack', None),
#  ('Connected2Fiber', None),
#  ('o9 Solutions', None),
#  ('Meituan', None),
#  ('OakNorth', None),
#  ('Shaw Academy', None),
#  ('Acast', None),
#  ('Holberton School', None),
#  ('Cambridge Quantum Computing', None),
#  ('VOI Technology', None),
#  ('Camino Financial', None),
#  ('Duo Security', None),
#  ('Tubi', None),
#  ('SimpliSafe', None),
#  ('Square Yards', None),
#  ('Eco', None),
#  ('Dashlane', None),
#  ('Kinta AI', None),
#  ('Kong', None),
#  ('Altonomy', None),
#  ('CryptoKitties', None),
#  ('EnsoData', None),
#  ('Keywords Studios', None),
#  ('Iterable', None),
#  ('Livspace', None),
#  ('Zomato', None),
#  ('Optimus Ride', None),
#  ('Piramal Enterprises', None),
#  ('Mahmee', None),
#  ('Salsify', None),
#  ('wefox', None),
#  ('FourKites', None),
#  ('Ubiquitous Energy', None),
#  ('CureVac', None),
#  ('Deutsche Bank', None),
#  ('Arctic Wolf', None),
#  ('Alibaba Cloud', None),
#  ('LegalZoom', None),
#  ('Acer', None),
#  ('Integrity Marketing Group', None),
#  ('Addepar', None),
#  ('StarkWare Industries', None),
#  ('Blind', None),
#  ('Aviatrix Systems', None),
#  ('Realworld', None),
#  ('Kneron', None),
#  ('3PL Central', None),
#  ('Current', None),
#  ('OnlineMedEd', None),
#  ('Ovia Health', None),
#  ('Boxed', None),
#  ('Indifi Technologies', None),
#  ('Uable', None),
#  ('FullStory', None),
#  ('WalkMe [Digital Adoption Platform]', None),
#  ('GreyOrange', None),
#  ('Pandion Therapeutics', None),
#  ('Kakao Mobility', None),
#  ('Convergint Technologies', None),
#  ('Redox', None),
#  ('Logi Analytics', None),
#  ('Coveo', None),
#  ('Exabeam', None),
#  ('Jupiter', None),
#  ('Pure Harvest Smart Farms', None),
#  ('InCred', None),
#  ('Fuzzy', None),
#  ('Infra.Market', None),
#  ('Lunar', None),
#  ('WorkChew', None),
#  ('Fictiv', None),
#  ('Tekion', None),
#  ('Cardlytics', None),
#  ('Truepill', None),
#  ('58.com', None),
#  ('CloudBees', None),
#  ('Clearcover', None),
#  ('Groove', None),
#  ('Novo Nordisk', None),
#  ('LinearB', None),
#  ('minu', None),
#  ('Stacks', None),
#  ('Clutter', None),
#  ('PathAI', None),
#  ('Digital House', None),
#  ('HYP3R', None),
#  ('InsurTech', None),
#  ('Magic Leap', None),
#  ('DailyPay', None),
#  ('Loom', None),
#  ('Inbox Health', None),
#  ('Iyuno Media Group', None),
#  ('Real', None),
#  ('Glovo', None),
#  ('FootPrint Coalition', None),
#  ('Precision BioSciences', None),
#  ('Xeris Pharmaceuticals', None),
#  ('BigID', None),
#  ('Visa', None),
#  ('Aurora Solar', None),
#  ('MGM Resorts International', None),
#  ('Greenlight Biosciences', None),
#  ('Employment Hero', None),
#  ('LongHash Ventures', None),
#  ('Indy', None),
#  ('True Balance', None),
#  ('Modulr', None),
#  ('Fanatiz', None),
#  ('Five Star Business Finance', None),
#  ('Founders First Capital Partners', None),
#  ('Bloomreach', None),
#  ('Sidecar Health', None),
#  ('Airtasker', None),
#  ...]

# %%
# %%sql
# SELECT *
# FROM Accounts;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 4112 rows affected.
# [(1, 1, 'Ascend Learning', 5, 'Closed Won', 'Closed', 10625, 16, datetime.datetime(2019, 9, 20, 0, 0), 8, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 17, 0, 0), 1),
#  (2, 1, 'NetPower', 98, '(1) Gain Access', 'Pipeline', 83250, 12, datetime.datetime(2019, 9, 13, 0, 0), 25, 'New Customer', datetime.datetime(2019, 10, 31, 0, 0), 2),
#  (3, 1, 'Blue Origin', 134, '(4) Propose Solution', 'Best Case', 153136, 12, datetime.datetime(2019, 7, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 22, 0, 0), 3),
#  (4, 1, 'Agilent Technologies, Inc', 119, '(3) Develop Solution', 'Pipeline', 30000, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (5, 2, 'AyP Mexico', 19, '(1) Gain Access', 'Pipeline', 15300, 12, datetime.datetime(2019, 11, 30, 0, 0), 14, 'New Customer', datetime.datetime(2019, 11, 30, 0, 0), 5),
#  (6, 3, 'Aboitiz Power Corporation', 406, '(5) Negotiate & Close', 'Pipeline', 90478, 60, datetime.datetime(2019, 4, 29, 0, 0), 11, 'New Customer', datetime.datetime(2019, 10, 24, 0, 0), 6),
#  (7, 3, 'Banco de Oro', 288, '(5) Negotiate & Close', 'Commit', 29644, 24, datetime.datetime(2019, 6, 14, 0, 0), 1, 'New Customer', datetime.datetime(2019, 10, 17, 0, 0), 6),
#  (8, 4, 'Falabella', 83, '(1) Gain Access', 'Pipeline', 70125, 12, datetime.datetime(2019, 12, 13, 0, 0), 2, 'New Customer', datetime.datetime(2020, 2, 7, 0, 0), 5),
#  (9, 1, 'State of Connecticut Department of Children & Families', 28, '(1) Gain Access', 'Pipeline', 30000, 12, datetime.datetime(2020, 2, 21, 0, 0), 3, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (10, 1, 'PUBLIC EMPLOYEES RETIREMENT SYSTEM, CALIFORNIA', 427, '(4) Propose Solution', 'Pipeline', 34200, 12, datetime.datetime(2019, 9, 26, 0, 0), 4, 'New Customer', datetime.datetime(2019, 10, 28, 0, 0), 3),
#  (11, 5, 'Teraxion', 40, '(1) Gain Access', 'Pipeline', 46750, 36, datetime.datetime(2019, 8, 31, 0, 0), 5, 'New Customer', datetime.datetime(2020, 2, 28, 0, 0), 1),
#  (12, 1, 'Tucson Electric Power Company Inc', 76, '(3) Develop Solution', 'Pipeline', 200685, 36, datetime.datetime(2019, 8, 31, 0, 0), 6, 'New Customer', datetime.datetime(2019, 12, 16, 0, 0), 3),
#  (13, 6, 'Rothbury Group Limited', 631, '(1) Gain Access', 'Pipeline', 29967, 36, datetime.datetime(2018, 4, 18, 0, 0), 7, 'New Customer', datetime.datetime(2020, 1, 20, 0, 0), 6),
#  (14, 1, 'Crowe', 62, '(1) Gain Access', 'Pipeline', 42500, 36, datetime.datetime(2019, 8, 31, 0, 0), 8, 'New Customer', datetime.datetime(2019, 12, 27, 0, 0), 1),
#  (15, 7, 'Tan Tock Seng Hospital', 459, '(1) Gain Access', 'Pipeline', 22500, 36, datetime.datetime(2018, 11, 20, 0, 0), 9, 'New Customer', datetime.datetime(2020, 1, 8, 0, 0), 6),
#  (16, 8, 'America Indochina Management', 67, '(1) Gain Access', 'Pipeline', 25000, 36, datetime.datetime(2019, 8, 31, 0, 0), 10, 'New Customer', datetime.datetime(2019, 12, 11, 0, 0), 6),
#  (17, 3, 'Department of Information and Communications Technology', 252, '(1) Gain Access', 'Pipeline', 170960, 36, datetime.datetime(2019, 2, 28, 0, 0), 11, 'New Customer', datetime.datetime(2020, 2, 19, 0, 0), 6),
#  (18, 9, 'Industrial and Commercial Bank of China (Thai) PCL', 459, '(1) Gain Access', 'Pipeline', 36932, 36, datetime.datetime(2018, 12, 11, 0, 0), 11, 'New Customer', datetime.datetime(2019, 12, 26, 0, 0), 6),
#  (19, 3, 'Integrated Microelectronics, Inc.', 98, '(1) Gain Access', 'Pipeline', 14400, 36, datetime.datetime(2020, 2, 20, 0, 0), 11, 'New Customer', datetime.datetime(2020, 2, 12, 0, 0), 6),
#  (20, 10, 'MAMPU: Malaysia Administrative Modernisation And Management Planning Unit Prime Minister?s Department', 75, '(3) Develop Solution', 'Pipeline', 60015, 12, datetime.datetime(2020, 1, 5, 0, 0), 11, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 5, 0, 0), 6),
#  (21, 10, 'Multimedia University', 242, '(3) Develop Solution', 'Pipeline', 51500, 36, datetime.datetime(2019, 2, 28, 0, 0), 11, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (22, 9, 'Provincial Electricity Authority', 530, '(2) Establish Needs', 'Pipeline', 51480, 24, datetime.datetime(2018, 12, 20, 0, 0), 11, 'New Customer', datetime.datetime(2020, 2, 25, 0, 0), 6),
#  (23, 9, 'PTT Oil and Retail Business Public Company Limited', 408, '(2) Establish Needs', 'Pipeline', 59080, 36, datetime.datetime(2018, 9, 12, 0, 0), 11, 'New Customer', datetime.datetime(2020, 2, 13, 0, 0), 6),
#  (24, 10, 'Royal Malaysian Police', 250, '(3) Develop Solution', 'Pipeline', 70000, 36, datetime.datetime(2019, 5, 21, 0, 0), 11, 'New Customer', datetime.datetime(2019, 11, 13, 0, 0), 6),
#  (25, 8, 'Saigon Bank', 553, '(1) Gain Access', 'Pipeline', 33480, 36, datetime.datetime(2018, 11, 14, 0, 0), 11, 'New Customer', datetime.datetime(2019, 12, 17, 0, 0), 6),
#  (26, 3, 'SM Retail', 336, '(1) Gain Access', 'Pipeline', 174740, 36, datetime.datetime(2018, 11, 30, 0, 0), 11, 'New Customer', datetime.datetime(2020, 2, 20, 0, 0), 6),
#  (27, 3, 'Sun Life', 67, '(3) Develop Solution', 'Pipeline', 110564, 36, datetime.datetime(2019, 8, 31, 0, 0), 11, 'New Customer', datetime.datetime(2020, 1, 28, 0, 0), 6),
#  (28, 10, "Touch 'n Go Sdn Bhd", 7, '(1) Gain Access', 'Pipeline', 20218, 36, datetime.datetime(2019, 11, 30, 0, 0), 11, 'New Customer', datetime.datetime(2019, 11, 30, 0, 0), 6),
#  (29, 10, 'UTSB Mnanagement Sdn Bhd.', 127, '(1) Gain Access', 'Pipeline', 12500, 24, datetime.datetime(2019, 8, 1, 0, 0), 11, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 13, 0, 0), 6),
#  (30, 1, 'HOWCO Group', 41, '(2) Establish Needs', 'Pipeline', 38500, 36, datetime.datetime(2019, 8, 30, 0, 0), 12, 'New Customer', datetime.datetime(2019, 12, 13, 0, 0), 2),
#  (31, 11, 'Organismo Nacional de Sanidad Pesquera ? SANIPES', 49, '(1) Gain Access', 'Pipeline', 26562, 12, datetime.datetime(2019, 9, 28, 0, 0), 13, 'New Customer', datetime.datetime(2019, 10, 25, 0, 0), 5),
#  (32, 2, 'KIO NETWORKS', 69, '(1) Gain Access', 'Pipeline', 65280, 5, datetime.datetime(2019, 8, 17, 0, 0), 14, 'Existing Customer - New Project', datetime.datetime(2019, 9, 30, 0, 0), 5),
#  (33, 11, 'ARPL Tecnologia Industrial SA', 215, '(3) Develop Solution', 'Pipeline', 28560, 12, datetime.datetime(2019, 2, 28, 0, 0), 15, 'New Customer', datetime.datetime(2020, 2, 14, 0, 0), 5),
#  (34, 2, 'CONDUSEF', 258, '(5) Negotiate & Close', 'Best Case', 21938, 12, datetime.datetime(2019, 8, 23, 0, 0), 15, 'New Customer', datetime.datetime(2019, 10, 15, 0, 0), 5),
#  (35, 12, 'Conte', 155, '(5) Negotiate & Close', 'Commit', 15300, 12, datetime.datetime(2019, 11, 15, 0, 0), 15, 'New Customer', datetime.datetime(2019, 10, 18, 0, 0), 5),
#  (36, 13, 'Government of Dominica', 545, '(5) Negotiate & Close', 'Pipeline', 53125, 36, datetime.datetime(2019, 8, 29, 0, 0), 15, 'New Customer', datetime.datetime(2019, 12, 20, 0, 0), 5),
#  (37, 14, 'Instituto Costarricense de Electricidad', 14, '(1) Gain Access', 'Pipeline', 143558, 12, datetime.datetime(2019, 11, 22, 0, 0), 15, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 22, 0, 0), 5),
#  (38, 15, 'SAT Guatemala', 503, '(5) Negotiate & Close', 'Pipeline', 58299, 12, datetime.datetime(2019, 6, 6, 0, 0), 15, 'New Customer', datetime.datetime(2019, 11, 15, 0, 0), 5),
#  (39, 4, 'Ministerio de Obras Publicas (MOP)', 210, '(1) Gain Access', 'Pipeline', 73950, 36, datetime.datetime(2019, 11, 15, 0, 0), 16, 'New Customer', datetime.datetime(2020, 1, 24, 0, 0), 5),
#  (40, 12, 'Secretaria Jurídica del Distrito', 113, '(4) Propose Solution', 'Pipeline', 30000, 12, datetime.datetime(2019, 8, 30, 0, 0), 17, 'New Customer', datetime.datetime(2019, 10, 31, 0, 0), 5),
#  (41, 12, 'Superintendencia de Industria y Comercio', 104, '(4) Propose Solution', 'Pipeline', 51000, 12, datetime.datetime(2020, 1, 31, 0, 0), 17, 'New Customer', datetime.datetime(2019, 11, 8, 0, 0), 5),
#  (42, 5, 'Arbor Memorial Services Inc', 138, '(1) Gain Access', 'Pipeline', 42000, 12, datetime.datetime(2019, 12, 2, 0, 0), 18, 'New Customer', datetime.datetime(2020, 2, 28, 0, 0), 1),
#  (43, 1, 'Emigrant Savings Bank', 413, 'Closed Won', 'Closed', 42880, 12, datetime.datetime(2019, 9, 30, 0, 0), 18, 'New Customer', datetime.datetime(2019, 9, 30, 0, 0), 1),
#  (44, 5, 'Kindred Credit Union', 11, '(1) Gain Access', 'Pipeline', 53760, 12, datetime.datetime(2019, 11, 30, 0, 0), 18, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (45, 5, 'M3P', 223, '(1) Gain Access', 'Pipeline', 128100, 12, datetime.datetime(2019, 2, 28, 0, 0), 18, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (46, 16, 'Vinod Patel and Company Ltd', 447, '(4) Propose Solution', 'Pipeline', 50908, 36, datetime.datetime(2018, 12, 24, 0, 0), 19, 'New Customer', datetime.datetime(2019, 12, 19, 0, 0), 6),
#  (47, 17, 'FUJIFILM Corporation', 222, '(1) Gain Access', 'Pipeline', 96537, 12, datetime.datetime(2019, 5, 17, 0, 0), 20, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 17, 0, 0), 2),
#  (48, 17, 'Transcosmos Technologic Arts Co., Ltd.', 420, '(1) Gain Access', 'Pipeline', 47283, 12, datetime.datetime(2018, 8, 31, 0, 0), 20, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 17, 0, 0), 2),
#  (49, 1, 'American National Bank & Trust', 63, '(2) Establish Needs', 'Pipeline', 24000, 12, datetime.datetime(2019, 8, 31, 0, 0), 21, 'New Customer', datetime.datetime(2020, 1, 24, 0, 0), 1),
#  (50, 18, '22', 147, '(2) Establish Needs', 'Pipeline', 65000, 36, datetime.datetime(2019, 5, 31, 0, 0), 22, 'New Customer', datetime.datetime(2019, 11, 13, 0, 0), 7),
#  (51, 7, 'Public Utilities Board', 222, '(1) Gain Access', 'Pipeline', 175568, 36, datetime.datetime(2019, 12, 17, 0, 0), 23, 'New Customer', datetime.datetime(2019, 12, 17, 0, 0), 6),
#  (52, 1, 'Dongbu Insurance', 266, '(4) Propose Solution', 'Pipeline', 24000, 60, datetime.datetime(2019, 3, 29, 0, 0), 24, 'New Customer', datetime.datetime(2019, 12, 20, 0, 0), 2),
#  (53, 1, 'Greenfence', 35, '(1) Gain Access', 'Pipeline', 120000, 12, datetime.datetime(2019, 8, 31, 0, 0), 24, 'New Customer', datetime.datetime(2020, 2, 14, 0, 0), 2),
#  (54, 1, 'Co-operative Insurance Company', 78, '(4) Propose Solution', 'Pipeline', 30000, 12, datetime.datetime(2019, 11, 29, 0, 0), 24, 'New Customer', datetime.datetime(2019, 11, 29, 0, 0), 1),
#  (55, 1, 'United Automobile Insurance Company', 68, '(1) Gain Access', 'Pipeline', 24000, 12, datetime.datetime(2019, 8, 31, 0, 0), 24, 'New Customer', datetime.datetime(2019, 11, 29, 0, 0), 1),
#  (56, 1, 'Ventiv Technology', 36, '(1) Gain Access', 'Pipeline', 60000, 12, datetime.datetime(2020, 2, 20, 0, 0), 24, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (57, 8, 'TTT Corporation', 523, '(1) Gain Access', 'Pipeline', 19271, 36, datetime.datetime(2018, 8, 15, 0, 0), 25, 'New Customer', datetime.datetime(2019, 12, 11, 0, 0), 6),
#  (58, 1, 'State of Oregon Department of Administration Services (DAS)', 979, '(1) Gain Access', 'Pipeline', 100000, 12, datetime.datetime(2017, 2, 28, 0, 0), 25, 'New Customer', datetime.datetime(2019, 12, 28, 0, 0), 3),
#  (59, 1, 'SYMETRA LIFE INSURANCE COMPANY', 387, 'Closed Won', 'Closed', 126080, 12, datetime.datetime(2020, 2, 26, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2020, 2, 26, 0, 0), 3),
#  (60, 1, 'American National Standards Institute', 125, '(1) Gain Access', 'Pipeline', 46500, 12, datetime.datetime(2020, 2, 21, 0, 0), 25, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (61, 5, 'CSA Group', 47, '(3) Develop Solution', 'Pipeline', 76800, 12, datetime.datetime(2019, 11, 22, 0, 0), 25, 'New Customer', datetime.datetime(2019, 11, 29, 0, 0), 1),
#  (62, 1, 'Rockland Trust Company', 155, '(3) Develop Solution', 'Pipeline', 142188, 12, datetime.datetime(2019, 12, 27, 0, 0), 25, 'New Customer', datetime.datetime(2019, 12, 27, 0, 0), 1),
#  (63, 10, ' Project Systems Corporation', 49, '(4) Propose Solution', 'Pipeline', 43750, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (64, 19, 'Alibaba Group', 558, '(1) Gain Access', 'Pipeline', 37500, 36, datetime.datetime(2018, 12, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (65, 1, 'Canon Business Professional Services (OEM)', 378, '(1) Gain Access', 'Pipeline', 100000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (66, 1, 'CloudDOCX (OEM)', 358, '(1) Gain Access', 'Pipeline', 25000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (67, 1, 'Crunch Technologies Corporation', 67, '(4) Propose Solution', 'Pipeline', 8750, 12, datetime.datetime(2019, 8, 31, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (68, 5, 'Curiato, Inc. (OEM)', 377, '(1) Gain Access', 'Pipeline', 50000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (69, 1, 'eLeadCRM (OEM)', 532, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2018, 8, 31, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (70, 1, 'Elixir Technologies Corporation', 133, '(4) Propose Solution', 'Pipeline', 4136, 12, datetime.datetime(2019, 8, 31, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (71, 1, 'EZOPS Inc (OEM)', 63, '(4) Propose Solution', 'Pipeline', 70000, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (72, 1, 'Flatirons Solutions Inc (OEM)', 769, '(1) Gain Access', 'Pipeline', 7500, 12, datetime.datetime(2018, 3, 31, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (73, 10, 'IPEC Project Systems Sdn Bhd', 50, '(4) Propose Solution', 'Pipeline', 25000, 12, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 9, 30, 0, 0), 4),
#  (74, 1, 'Iron Mountain, Inc', 413, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2018, 11, 30, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (75, 1, 'Kronos Incorporated', 42, 'Closed Won', 'Closed', 33000, 12, datetime.datetime(2019, 9, 20, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 9, 20, 0, 0), 4),
#  (76, 1, 'Link Technology Group', 85, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 15, 0, 0), 4),
#  (77, 1, 'MoxiWorks', 138, '(2) Establish Needs', 'Pipeline', 25000, 12, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 15, 0, 0), 4),
#  (78, 5, 'Mutual Concept Computer Group Inc. (OEM)', 8, 'Closed Won', 'Closed', 8860, 12, datetime.datetime(2019, 9, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 9, 18, 0, 0), 4),
#  (79, 1, 'National Association of Insurance Commissioners', 18, '(3) Develop Solution', 'Pipeline', 126563, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (80, 1, 'National Sports Academy', 25, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (81, 5, 'New Machine Computer Group Inc.', 3, 'Closed Won', 'Closed', 8860, 12, datetime.datetime(2019, 10, 4, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 9, 26, 0, 0), 4),
#  (82, 1, 'Omnicon Group (OEM)', 315, '(1) Gain Access', 'Pipeline', 50000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (83, 1, 'Orbis Technologies, Inc.', 130, '(2) Establish Needs', 'Pipeline', 25000, 12, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (84, 20, 'RioSoft (OEM)', 404, '(1) Gain Access', 'Pipeline', 50000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (85, 1, 'Sapiens Americas', 190, '(5) Negotiate & Close', 'Pipeline', 81000, 12, datetime.datetime(2019, 5, 15, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (86, 1, 'Thomson Reuters', 1141, '(1) Gain Access', 'Pipeline', 125000, 12, datetime.datetime(2016, 8, 31, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (87, 1, 'Toppan Merrill', 41, '(4) Propose Solution', 'Pipeline', 13000, 12, datetime.datetime(2020, 2, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (88, 17, 'West Coast Electric Corporation', 12, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (89, 1, 'Xerox DocuShare (OEM)', 762, '(2) Establish Needs', 'Pipeline', 48000, 36, datetime.datetime(2017, 8, 31, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 15, 0, 0), 4),
#  (90, 17, 'Yokogawa Electric Corporation', 7, '(3) Develop Solution', 'Pipeline', 25000, 12, datetime.datetime(2019, 11, 15, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 11, 15, 0, 0), 4),
#  (91, 1, 'Accurate Background', 48, '(1) Gain Access', 'Pipeline', 56250, 12, datetime.datetime(2019, 9, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 14, 0, 0), 2),
#  (92, 1, 'Lexipol LLC', 145, '(4) Propose Solution', 'Pipeline', 139349, 36, datetime.datetime(2019, 8, 16, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 31, 0, 0), 2),
#  (93, 1, 'Los Angeles Unified School District', 82, '(2) Establish Needs', 'Pipeline', 125000, 36, datetime.datetime(2020, 1, 17, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 17, 0, 0), 2),
#  (94, 1, 'Michaels Stores, Inc.', 270, '(2) Establish Needs', 'Pipeline', 52000, 36, datetime.datetime(2019, 1, 14, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 2, 14, 0, 0), 2),
#  (95, 1, 'NextSphere Technologies', 614, '(1) Gain Access', 'Pipeline', 68150, 12, datetime.datetime(2019, 9, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 14, 0, 0), 2),
#  (96, 1, 'SAE International', 641, '(1) Gain Access', 'Pipeline', 65000, 24, datetime.datetime(2018, 12, 28, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 31, 0, 0), 2),
#  (97, 1, 'Social Finance, Inc.', 47, '(1) Gain Access', 'Pipeline', 62500, 12, datetime.datetime(2019, 8, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 13, 0, 0), 2),
#  (98, 1, 'SOUTHWEST BUSINESS CORPORATION', 1097, '(1) Gain Access', 'Pipeline', 85000, 12, datetime.datetime(2016, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 14, 0, 0), 2),
#  (99, 1, 'UCLA', 222, '(5) Negotiate & Close', 'Commit', 56250, 12, datetime.datetime(2019, 9, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 11, 0, 0), 2),
#  (100, 1, 'University of California, Agriculture and Natural Resources', 5, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 17, 0, 0), 2),
#  (101, 21, '4DX', 98, '(3) Develop Solution', 'Pipeline', 11985, 36, datetime.datetime(2019, 12, 18, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (102, 19, 'Accenture China', 7, '(1) Gain Access', 'Pipeline', 60000, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 15, 0, 0), 6),
#  (103, 7, 'ACCENTURE PTE LTD', 146, '(1) Gain Access', 'Pipeline', 80000, 36, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 19, 0, 0), 6),
#  (104, 22, 'AIA Hong Kong', 50, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 15, 0, 0), 6),
#  (105, 7, 'Allianz SE Singapore Branch', 365, '(1) Gain Access', 'Pipeline', 40000, 36, datetime.datetime(2018, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 19, 0, 0), 6),
#  (106, 21, 'Aqsacom', 154, '(1) Gain Access', 'Pipeline', 21851, 36, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 12, 0, 0), 6),
#  (107, 19, 'Beijing Shouhuan Cultural Tourism Investment Co., Ltd.', 78, '(1) Gain Access', 'Pipeline', 125000, 36, datetime.datetime(2019, 12, 10, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 10, 0, 0), 6),
#  (108, 22, 'Bureau Veritas HK Ltd.', 372, '(5) Negotiate & Close', 'Best Case', 39960, 36, datetime.datetime(2019, 10, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 31, 0, 0), 6),
#  (109, 22, 'Central Bank', 160, '(2) Establish Needs', 'Pipeline', 54638, 36, datetime.datetime(2019, 8, 23, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 23, 0, 0), 6),
#  (110, 22, 'Cognizant Technology Solutions Hong Kong Ltd', 554, '(4) Propose Solution', 'Pipeline', 11167, 12, datetime.datetime(2018, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (111, 21, 'Department of Parliamentary Services', 224, '(1) Gain Access', 'Pipeline', 50000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 11, 0, 0), 6),
#  (112, 21, 'Eclipx Group Limited', 432, '(4) Propose Solution', 'Pipeline', 13877, 36, datetime.datetime(2019, 7, 29, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 2, 0, 0), 6),
#  (113, 7, 'Enterprise Singapore', 394, '(1) Gain Access', 'Pipeline', 42500, 48, datetime.datetime(2018, 12, 18, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 19, 0, 0), 6),
#  (114, 19, 'GE Digital China', 335, '(1) Gain Access', 'Pipeline', 52500, 36, datetime.datetime(2019, 2, 21, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 6, 0, 0), 6),
#  (115, 21, 'GENIX VENTURES PTY LTD', 421, '(1) Gain Access', 'Pipeline', 1724, 36, datetime.datetime(2018, 11, 20, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 13, 0, 0), 6),
#  (116, 3, 'i3esolutions, inc', 34, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (117, 21, 'Icare NSW', 1, '(1) Gain Access', 'Pipeline', 63850, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 12, 0, 0), 6),
#  (118, 7, 'James Cook University Singapore', 76, '(5) Negotiate & Close', 'Best Case', 33750, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 25, 0, 0), 6),
#  (119, 22, 'Li & Fung (Trading) Limited', 285, '(2) Establish Needs', 'Pipeline', 7200, 24, datetime.datetime(2019, 1, 30, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (120, 21, 'LINK MARKET SERVICES GROUP PTY LIMITED', 128, '(1) Gain Access', 'Pipeline', 222282, 36, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 20, 0, 0), 6),
#  (121, 21, 'MINTER ELLISON LAWYERS', 454, '(1) Gain Access', 'Pipeline', 72363, 36, datetime.datetime(2019, 2, 19, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 5, 0, 0), 6),
#  (122, 21, 'NATIONAL AUSTRALIA BANK LIMITED', 363, '(2) Establish Needs', 'Pipeline', 378756, 36, datetime.datetime(2019, 2, 12, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 26, 0, 0), 6),
#  (123, 19, 'NCSI', 422, '(1) Gain Access', 'Pipeline', 40000, 36, datetime.datetime(2018, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (124, 21, 'News Pty Limited', 481, '(1) Gain Access', 'Pipeline', 35061, 36, datetime.datetime(2018, 12, 25, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 17, 0, 0), 6),
#  (125, 21, 'NSW DEPARTMENT OF POLICE AND JUSTICE', 218, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (126, 21, 'Prudential Investment Company of Australia', 0, '(1) Gain Access', 'Pipeline', 46823, 36, datetime.datetime(2019, 12, 25, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 25, 0, 0), 6),
#  (127, 19, 'SIEBRENET Inc.', 221, '(1) Gain Access', 'Pipeline', 35000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 19, 0, 0), 6),
#  (128, 22, 'Standard Chartered Bank', 58, '(2) Establish Needs', 'Pipeline', 90000, 12, datetime.datetime(2019, 9, 10, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 21, 0, 0), 6),
#  (129, 21, 'TABCORP HOLDINGS LIMITED', 13, '(1) Gain Access', 'Pipeline', 35472, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 17, 0, 0), 6),
#  (130, 21, 'TELSTRA HOLDINGS PTY LTD', 616, '(1) Gain Access', 'Pipeline', 141108, 36, datetime.datetime(2018, 10, 17, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 13, 0, 0), 6),
#  (131, 7, 'UFINITY GROUP LIMITED', 379, '(1) Gain Access', 'Pipeline', 36000, 36, datetime.datetime(2018, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 6),
#  (132, 8, 'Vietnam Electricity', 98, '(1) Gain Access', 'Pipeline', 28000, 36, datetime.datetime(2020, 2, 19, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 20, 0, 0), 6),
#  (133, 22, 'Welab Holdings', 7, '(1) Gain Access', 'Pipeline', 58125, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 30, 0, 0), 6),
#  (134, 4, 'Bice Vida Compañía De Seguros', 15, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 24, 0, 0), 5),
#  (135, 12, 'Colmena Seguros', 49, '(1) Gain Access', 'Pipeline', 60000, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 7, 0, 0), 5),
#  (136, 2, 'Pentafon', 22, '(1) Gain Access', 'Pipeline', 15000, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 5),
#  (137, 12, 'Procargo Port', 54, '(1) Gain Access', 'Pipeline', 20000, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 7, 0, 0), 5),
#  (138, 23, 'SOGE Bank', 147, '(3) Develop Solution', 'Pipeline', 33750, 12, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 20, 0, 0), 5),
#  (139, 24, 'St. Lucia - Government of Information Technology', 40, '(1) Gain Access', 'Pipeline', 30000, 12, datetime.datetime(2019, 11, 22, 0, 0), None, 'New Customer', datetime.datetime(2019, 11, 29, 0, 0), 5),
#  (140, 25, 'ZURICH SANTANDER - Uruguay', 64, '(1) Gain Access', 'Pipeline', 20000, 36, datetime.datetime(2019, 8, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 24, 0, 0), 5),
#  (141, 1, 'Boeing DMS', 1021, '(1) Gain Access', 'Pipeline', 200000, 12, datetime.datetime(2018, 2, 28, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 28, 0, 0), 3),
#  (142, 1, 'California DOJ', 1085, '(3) Develop Solution', 'Pipeline', 23767, 36, datetime.datetime(2018, 10, 1, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 15, 0, 0), 3),
#  (143, 1, 'CoreLogic Inc, Solutions, LLC', 424, '(4) Propose Solution', 'Pipeline', 275000, 36, datetime.datetime(2018, 10, 19, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 22, 0, 0), 3),
#  (144, 1, 'Google Inc', 166, '(1) Gain Access', 'Pipeline', 30000, 36, datetime.datetime(2019, 5, 31, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2019, 12, 16, 0, 0), 3),
#  (145, 1, 'Intel Corporation', 215, '(1) Gain Access', 'Pipeline', 125000, 36, datetime.datetime(2019, 2, 28, 0, 0), None, 'Existing Customer - New Project', datetime.datetime(2020, 2, 28, 0, 0), 3),
#  (146, 1, 'Oregon Department of Human Services', 113, '(2) Establish Needs', 'Pipeline', 165034, 36, datetime.datetime(2020, 2, 15, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 3),
#  (147, 1, 'Robert Half International Inc', 1079, '(3) Develop Solution', 'Pipeline', 48000, 25, datetime.datetime(2019, 9, 30, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 23, 0, 0), 3),
#  (148, 1, 'TOYOTA MOTOR CREDIT CORPORATION', 7, '(1) Gain Access', 'Pipeline', 125000, 36, datetime.datetime(2019, 11, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 15, 0, 0), 3),
#  (149, 1, 'Wells Fargo & Company AZ', 610, '(4) Propose Solution', 'Best Case', 87500, 12, datetime.datetime(2018, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 18, 0, 0), 3),
#  (150, 1, 'Wells Fargo Bank, N.A.', 224, '(5) Negotiate & Close', 'Commit', 250000, 12, datetime.datetime(2019, 9, 30, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 15, 0, 0), 3),
#  (151, 1, 'Boost Insurance', 55, '(3) Develop Solution', 'Pipeline', 31875, 12, datetime.datetime(2019, 11, 22, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 25, 0, 0), 1),
#  (152, 1, 'Quality Steel Corporation', 18, '(1) Gain Access', 'Pipeline', 48000, 12, datetime.datetime(2020, 2, 21, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (153, 1, 'ScienceLogic', 4, '(1) Gain Access', 'Pipeline', 48000, 12, datetime.datetime(2020, 2, 21, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (154, 1, 'Spruce Technology', 256, '(1) Gain Access', 'Pipeline', 56250, 12, datetime.datetime(2019, 2, 28, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 21, 0, 0), 1),
#  (155, 17, 'SoftBank', 27, '(4) Propose Solution', 'Best Case', 294015, 15, datetime.datetime(2019, 8, 29, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 6, 16, 0, 0), 1),
#  (156, 1, 'Compass', 22, '(3) Develop Solution', 'Commit', 334170, 17, datetime.datetime(2017, 1, 30, 0, 0), 7, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 14, 0, 0), 5),
#  (157, 26, 'Deliveroo', 89, '(4) Propose Solution', 'Best Case', 145636, 18, datetime.datetime(2016, 4, 26, 0, 0), 22, 'Existing Customer - Upsell', datetime.datetime(2020, 11, 27, 0, 0), 1),
#  (158, 1, 'Citigroup', 46, 'Closed won', 'Closed', 90962, 34, datetime.datetime(2017, 5, 28, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 13, 0, 0), 3),
#  (159, 27, 'Spotify', 47, '(4) Propose Solution', 'Best Case', 57301, 24, datetime.datetime(2017, 9, 20, 0, 0), 18, 'New Customer', datetime.datetime(2020, 7, 22, 0, 0), 1),
#  (160, 19, 'Ant Group', 87, '(1) Gain Access', 'Commit', 66421, 20, datetime.datetime(2016, 2, 20, 0, 0), 16, 'New Customer', datetime.datetime(2020, 12, 12, 0, 0), 3),
#  (161, 1, 'IBM', 28, '(5) Negotiate & Close', 'Best Case', 329942, 19, datetime.datetime(2019, 8, 8, 0, 0), 10, 'Existing Customer - Upsell', datetime.datetime(2020, 12, 5, 0, 0), 3),
#  (162, 26, 'Crowdcube', 30, '(3) Develop Solution', 'Commit', 373200, 34, datetime.datetime(2017, 10, 18, 0, 0), 15, 'Existing Customer - Upsell', datetime.datetime(2020, 8, 5, 0, 0), 3),
#  (163, 1, 'BetterUp', 26, '(3) Develop Solution', 'Pipeline', 286184, 13, datetime.datetime(2016, 2, 11, 0, 0), 12, 'New Customer', datetime.datetime(2019, 6, 4, 0, 0), 3),
#  (164, 5, 'Shopify', 86, '(4) Propose Solution', 'Best Case', 387795, 13, datetime.datetime(2020, 2, 6, 0, 0), 21, 'Existing Customer - Upsell', datetime.datetime(2019, 2, 8, 0, 0), 2),
#  (165, 1, 'DraftKings', 34, 'Closed won', 'Commit', 10260, 27, datetime.datetime(2016, 3, 31, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2020, 3, 24, 0, 0), 1),
#  (166, 1, 'Ripple', 80, 'Closed won', 'Pipeline', 226972, 12, datetime.datetime(2019, 6, 29, 0, 0), 9, 'New Customer', datetime.datetime(2020, 1, 3, 0, 0), 6),
#  (167, 1, 'Facebook', 36, 'Closed Lost', 'Commit', 249402, 18, datetime.datetime(2017, 11, 27, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 27, 0, 0), 4),
#  (168, 1, 'Goldman Sachs', 11, '(4) Propose Solution', 'Best Case', 54846, 14, datetime.datetime(2016, 1, 21, 0, 0), 23, 'Existing Customer - Upsell', datetime.datetime(2020, 12, 30, 0, 0), 4),
#  (169, 1, 'Coursera', 28, 'Closed Lost', 'Pipeline', 26861, 27, datetime.datetime(2018, 3, 22, 0, 0), 2, 'Existing Customer - Upsell', datetime.datetime(2020, 9, 11, 0, 0), 4),
#  (170, 1, 'Apple', 14, '(4) Propose Solution', 'Best Case', 13125, 36, datetime.datetime(2020, 9, 26, 0, 0), 18, 'New Customer', datetime.datetime(2019, 11, 21, 0, 0), 2),
#  (171, 18, 'CRED', 55, 'Closed won', 'Best Case', 122519, 15, datetime.datetime(2017, 12, 6, 0, 0), 18, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 22, 0, 0), 1),
#  (172, 1, 'Apollo', 42, '(2) Establish Needs', 'Best Case', 50968, 20, datetime.datetime(2020, 4, 8, 0, 0), 6, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 7, 0, 0), 1),
#  (173, 1, 'Twilio', 90, '(5) Negotiate & Close', 'Commit', 37638, 12, datetime.datetime(2016, 1, 30, 0, 0), 9, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 10, 0, 0), 2),
#  (174, 1, 'Calendly', 79, 'Closed Lost', 'Best Case', 375680, 28, datetime.datetime(2020, 6, 15, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 4, 0, 0), 5),
#  (175, 1, 'Intel', 17, '(1) Gain Access', 'Pipeline', 65721, 33, datetime.datetime(2018, 6, 9, 0, 0), None, 'New Customer', datetime.datetime(2019, 4, 25, 0, 0), 4),
#  (176, 28, 'Nokia', 30, '(2) Establish Needs', 'Commit', 285827, 21, datetime.datetime(2018, 2, 8, 0, 0), 5, 'Existing Customer - Upsell', datetime.datetime(2019, 5, 15, 0, 0), 4),
#  (177, 1, 'Square', 89, '(3) Develop Solution', 'Best Case', 321046, 24, datetime.datetime(2018, 5, 26, 0, 0), 10, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 27, 0, 0), 5),
#  (178, 1, 'Pipe', 70, '(4) Propose Solution', 'Commit', 202863, 32, datetime.datetime(2019, 8, 2, 0, 0), 17, 'Existing Customer - Upsell', datetime.datetime(2019, 3, 2, 0, 0), 6),
#  (179, 1, 'Twitch', 4, 'Closed won', 'Pipeline', 162764, 16, datetime.datetime(2020, 11, 14, 0, 0), 12, 'New Customer', datetime.datetime(2020, 12, 12, 0, 0), 2),
#  (180, 1, 'Epic Games', 32, 'Closed won', 'Commit', 160653, 18, datetime.datetime(2018, 1, 1, 0, 0), 3, 'New Customer', datetime.datetime(2019, 2, 6, 0, 0), 2),
#  (181, 1, 'Cityblock Health', 15, '(2) Establish Needs', 'Pipeline', 235219, 23, datetime.datetime(2020, 10, 16, 0, 0), 3, 'New Customer', datetime.datetime(2020, 11, 13, 0, 0), 1),
#  (182, 1, 'Roku', 41, '(4) Propose Solution', 'Commit', 207399, 31, datetime.datetime(2016, 2, 11, 0, 0), 18, 'Existing Customer - Upsell', datetime.datetime(2019, 7, 28, 0, 0), 6),
#  (183, 1, 'ThredUp', 79, 'Closed won', 'Pipeline', 313340, 20, datetime.datetime(2017, 11, 13, 0, 0), 16, 'Existing Customer - Upsell', datetime.datetime(2020, 4, 17, 0, 0), 1),
#  (184, 1, 'Squarespace', 99, '(5) Negotiate & Close', 'Pipeline', 300489, 29, datetime.datetime(2020, 10, 28, 0, 0), 5, 'New Customer', datetime.datetime(2020, 10, 23, 0, 0), 1),
#  (185, 19, 'Tencent', 13, 'Closed won', 'Best Case', 350965, 15, datetime.datetime(2020, 12, 31, 0, 0), 4, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 16, 0, 0), 4),
#  (186, 1, 'StockX', 92, '(2) Establish Needs', 'Commit', 380512, 28, datetime.datetime(2018, 4, 11, 0, 0), 21, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 27, 0, 0), 5),
#  (187, 26, 'TrueLayer', 76, '(3) Develop Solution', 'Commit', 167879, 21, datetime.datetime(2019, 5, 15, 0, 0), 19, 'New Customer', datetime.datetime(2020, 6, 30, 0, 0), 6),
#  (188, 1, 'Twitter', 67, 'Closed Lost', 'Best Case', 250350, 21, datetime.datetime(2016, 5, 14, 0, 0), 1, 'New Customer', datetime.datetime(2020, 9, 16, 0, 0), 5),
#  (189, 29, 'OurCrowd', 59, 'Closed won', 'Best Case', 390061, 34, datetime.datetime(2018, 1, 9, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 6, 0, 0), 2),
#  (190, 1, 'Gopuff', 42, '(2) Establish Needs', 'Pipeline', 102036, 35, datetime.datetime(2017, 5, 26, 0, 0), 8, 'New Customer', datetime.datetime(2020, 5, 4, 0, 0), 1),
#  (191, 1, 'Okta', 27, '(2) Establish Needs', 'Best Case', 385833, 18, datetime.datetime(2019, 1, 1, 0, 0), 19, 'New Customer', datetime.datetime(2019, 3, 27, 0, 0), 5),
#  (192, 1, 'Nazara Technologies', 13, 'Closed Lost', 'Pipeline', 154995, 15, datetime.datetime(2017, 1, 25, 0, 0), 16, 'New Customer', datetime.datetime(2020, 8, 22, 0, 0), 4),
#  (193, 1, 'Drift', 100, '(5) Negotiate & Close', 'Pipeline', 53132, 30, datetime.datetime(2016, 7, 11, 0, 0), 17, 'New Customer', datetime.datetime(2019, 11, 3, 0, 0), 6),
#  (194, 19, 'Lenovo', 37, '(1) Gain Access', 'Best Case', 380262, 22, datetime.datetime(2016, 8, 18, 0, 0), 5, 'Existing Customer - Upsell', datetime.datetime(2020, 3, 12, 0, 0), 4),
#  (195, 1, 'NYDIG', 16, '(3) Develop Solution', 'Commit', 200557, 23, datetime.datetime(2017, 6, 3, 0, 0), 4, 'New Customer', datetime.datetime(2020, 10, 18, 0, 0), 3),
#  (196, 1, 'Ro', 3, '(4) Propose Solution', 'Best Case', 254234, 23, datetime.datetime(2019, 6, 16, 0, 0), 8, 'New Customer', datetime.datetime(2019, 7, 1, 0, 0), 6),
#  (197, 1, 'Pindrop', 34, '(3) Develop Solution', 'Pipeline', 246693, 16, datetime.datetime(2019, 5, 31, 0, 0), None, 'New Customer', datetime.datetime(2020, 6, 22, 0, 0), 4),
#  (198, 17, 'Rakuten', 1, 'Closed won', 'Pipeline', 66933, 31, datetime.datetime(2019, 9, 25, 0, 0), 3, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 10, 0, 0), 2),
#  (199, 1, 'BlocPower', 34, '(4) Propose Solution', 'Best Case', 51640, 25, datetime.datetime(2017, 9, 23, 0, 0), 25, 'New Customer', datetime.datetime(2020, 8, 4, 0, 0), 1),
#  (200, 1, 'NVIDIA', 96, 'Closed Lost', 'Best Case', 2613, 29, datetime.datetime(2019, 7, 20, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 24, 0, 0), 4),
#  (201, 1, 'DigitalOcean', 84, '(2) Establish Needs', 'Commit', 61841, 14, datetime.datetime(2017, 5, 18, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 23, 0, 0), 1),
#  (202, 1, 'SoFi', 20, '(4) Propose Solution', 'Best Case', 188625, 29, datetime.datetime(2018, 1, 30, 0, 0), 18, 'New Customer', datetime.datetime(2020, 5, 13, 0, 0), 2),
#  (203, 30, 'Daimler', 58, '(1) Gain Access', 'Commit', 117204, 17, datetime.datetime(2018, 2, 27, 0, 0), 25, 'New Customer', datetime.datetime(2019, 11, 29, 0, 0), 4),
#  (204, 1, 'OneTrust', 88, '(4) Propose Solution', 'Commit', 367210, 32, datetime.datetime(2019, 6, 28, 0, 0), 17, 'Existing Customer - Upsell', datetime.datetime(2019, 6, 2, 0, 0), 1),
#  (205, 18, 'PharmEasy', 100, '(3) Develop Solution', 'Best Case', 190335, 25, datetime.datetime(2019, 7, 11, 0, 0), 20, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 27, 0, 0), 4),
#  (206, 19, 'Bilibili', 71, '(1) Gain Access', 'Pipeline', 134284, 26, datetime.datetime(2020, 2, 6, 0, 0), 5, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 29, 0, 0), 5),
#  (207, 1, 'Pacaso', 87, 'Closed won', 'Commit', 4358, 24, datetime.datetime(2017, 7, 7, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2020, 12, 9, 0, 0), 2),
#  (208, 1, 'Next Insurance', 7, '(2) Establish Needs', 'Best Case', 53540, 24, datetime.datetime(2020, 9, 18, 0, 0), 13, 'New Customer', datetime.datetime(2020, 4, 12, 0, 0), 4),
#  (209, 1, 'Newchip', 13, '(1) Gain Access', 'Best Case', 302287, 13, datetime.datetime(2016, 3, 23, 0, 0), 4, 'Existing Customer - Upsell', datetime.datetime(2020, 7, 30, 0, 0), 5),
#  (210, 1, 'BlackRock', 37, '(5) Negotiate & Close', 'Commit', 114801, 20, datetime.datetime(2019, 3, 24, 0, 0), 2, 'Existing Customer - Upsell', datetime.datetime(2020, 3, 26, 0, 0), 1),
#  (211, 1, 'Cruise', 26, '(4) Propose Solution', 'Commit', 63482, 12, datetime.datetime(2018, 2, 21, 0, 0), 25, 'New Customer', datetime.datetime(2020, 12, 3, 0, 0), 4),
#  (212, 1, 'maude', 11, 'Closed won', 'Pipeline', 59809, 19, datetime.datetime(2019, 11, 30, 0, 0), 9, 'New Customer', datetime.datetime(2020, 2, 13, 0, 0), 4),
#  (213, 30, 'ATAI Life Sciences', 86, '(2) Establish Needs', 'Pipeline', 380346, 32, datetime.datetime(2016, 8, 23, 0, 0), 11, 'New Customer', datetime.datetime(2019, 4, 8, 0, 0), 2),
#  (214, 1, 'OpenSea', 41, '(1) Gain Access', 'Commit', 103379, 15, datetime.datetime(2018, 9, 24, 0, 0), 14, 'New Customer', datetime.datetime(2020, 9, 13, 0, 0), 3),
#  (215, 1, 'Docker', 46, '(2) Establish Needs', 'Commit', 373111, 12, datetime.datetime(2017, 2, 7, 0, 0), 13, 'New Customer', datetime.datetime(2019, 12, 21, 0, 0), 2),
#  (216, 19, 'NIO', 22, '(1) Gain Access', 'Best Case', 18278, 31, datetime.datetime(2020, 5, 27, 0, 0), 12, 'Existing Customer - Upsell', datetime.datetime(2020, 11, 29, 0, 0), 2),
#  (217, 1, 'Stripe', 89, '(3) Develop Solution', 'Commit', 361448, 27, datetime.datetime(2016, 2, 1, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 5, 15, 0, 0), 1),
#  (218, 1, 'The Honest Company', 41, 'Closed won', 'Pipeline', 219464, 32, datetime.datetime(2020, 3, 22, 0, 0), None, 'New Customer', datetime.datetime(2019, 4, 14, 0, 0), 2),
#  (219, 1, 'Jumio', 45, '(2) Establish Needs', 'Commit', 377797, 27, datetime.datetime(2019, 4, 1, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 30, 0, 0), 4),
#  (220, 21, 'Airwallex', 85, '(2) Establish Needs', 'Commit', 120087, 21, datetime.datetime(2018, 3, 24, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 31, 0, 0), 2),
#  (221, 18, 'Groww', 66, '(4) Propose Solution', 'Commit', 22358, 33, datetime.datetime(2019, 1, 31, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 12, 10, 0, 0), 1),
#  (222, 1, 'Redis Labs', 0, '(3) Develop Solution', 'Best Case', 321443, 26, datetime.datetime(2020, 5, 19, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 8, 0, 0), 5),
#  (223, 5, 'Hopper', 2, '(4) Propose Solution', 'Best Case', 311803, 23, datetime.datetime(2016, 9, 9, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 24, 0, 0), 2),
#  (224, 1, 'Ironclad', 25, '(4) Propose Solution', 'Pipeline', 159837, 25, datetime.datetime(2020, 12, 6, 0, 0), None, 'New Customer', datetime.datetime(2020, 9, 10, 0, 0), 5),
#  (225, 1, 'Cyble', 96, '(4) Propose Solution', 'Pipeline', 250561, 25, datetime.datetime(2020, 2, 19, 0, 0), None, 'New Customer', datetime.datetime(2019, 9, 11, 0, 0), 4),
#  (226, 1, 'DocuSign', 93, 'Closed Lost', 'Best Case', 322265, 34, datetime.datetime(2018, 6, 16, 0, 0), None, 'New Customer', datetime.datetime(2019, 3, 14, 0, 0), 6),
#  (227, 1, 'Silver Lake', 80, '(4) Propose Solution', 'Pipeline', 264222, 17, datetime.datetime(2019, 1, 10, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 29, 0, 0), 4),
#  (228, 1, 'Box', 27, 'Closed won', 'Commit', 367748, 28, datetime.datetime(2018, 2, 21, 0, 0), None, 'New Customer', datetime.datetime(2019, 7, 22, 0, 0), 2),
#  (229, 1, 'CrowdStrike', 76, '(4) Propose Solution', 'Pipeline', 51880, 30, datetime.datetime(2018, 11, 18, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 9, 0, 0), 2),
#  (230, 1, 'Outreach', 24, '(2) Establish Needs', 'Commit', 360098, 24, datetime.datetime(2018, 8, 16, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 14, 0, 0), 1),
#  (231, 18, 'Unacademy', 35, '(4) Propose Solution', 'Pipeline', 220554, 15, datetime.datetime(2018, 3, 25, 0, 0), None, 'New Customer', datetime.datetime(2019, 8, 17, 0, 0), 1),
#  (232, 1, 'Verkada', 100, '(2) Establish Needs', 'Best Case', 267990, 14, datetime.datetime(2017, 9, 10, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 5, 2, 0, 0), 6),
#  (233, 26, 'Seedrs', 96, '(1) Gain Access', 'Commit', 307476, 13, datetime.datetime(2020, 10, 30, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 12, 3, 0, 0), 3),
#  (234, 1, 'Skydio', 41, '(1) Gain Access', 'Pipeline', 298364, 14, datetime.datetime(2020, 12, 25, 0, 0), None, 'New Customer', datetime.datetime(2019, 8, 28, 0, 0), 3),
#  (235, 1, 'GupShup', 17, '(1) Gain Access', 'Best Case', 176302, 33, datetime.datetime(2017, 5, 22, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 25, 0, 0), 1),
#  (236, 1, 'Cowbell Cyber', 63, '(3) Develop Solution', 'Commit', 263308, 30, datetime.datetime(2020, 3, 28, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 4, 13, 0, 0), 4),
#  (237, 1, 'SecurityScorecard', 82, '(4) Propose Solution', 'Pipeline', 215284, 30, datetime.datetime(2016, 11, 8, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 6, 0, 0), 6),
#  (238, 26, 'Draper Esprit', 3, '(1) Gain Access', 'Commit', 216896, 34, datetime.datetime(2017, 8, 21, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 7, 25, 0, 0), 1),
#  (239, 7, 'Trax', 32, '(2) Establish Needs', 'Best Case', 99653, 22, datetime.datetime(2020, 6, 28, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 10, 11, 0, 0), 4),
#  (240, 1, 'Dropbox', 45, 'Closed won', 'Best Case', 155399, 25, datetime.datetime(2019, 8, 28, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 27, 0, 0), 4),
#  (241, 1, 'Airtable', 75, '(1) Gain Access', 'Best Case', 308038, 19, datetime.datetime(2018, 11, 21, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 20, 0, 0), 3),
#  (242, 1, 'Bitwise Industries', 25, 'Closed Lost', 'Best Case', 130851, 17, datetime.datetime(2017, 6, 20, 0, 0), None, 'New Customer', datetime.datetime(2019, 3, 1, 0, 0), 4),
#  (243, 26, 'SumUp', 55, '(5) Negotiate & Close', 'Best Case', 47560, 19, datetime.datetime(2019, 5, 9, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 30, 0, 0), 2),
#  (244, 1, 'BNY Mellon', 39, '(4) Propose Solution', 'Pipeline', 112312, 32, datetime.datetime(2019, 6, 20, 0, 0), None, 'New Customer', datetime.datetime(2019, 8, 25, 0, 0), 6),
#  (245, 29, 'eToro', 98, '(3) Develop Solution', 'Commit', 86340, 13, datetime.datetime(2020, 5, 19, 0, 0), None, 'New Customer', datetime.datetime(2020, 4, 6, 0, 0), 3),
#  (246, 27, 'Northvolt', 72, '(4) Propose Solution', 'Best Case', 48422, 19, datetime.datetime(2017, 8, 30, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 17, 0, 0), 2),
#  (247, 1, 'Dataminr', 98, 'Closed Lost', 'Pipeline', 282203, 22, datetime.datetime(2018, 9, 20, 0, 0), None, 'New Customer', datetime.datetime(2020, 12, 28, 0, 0), 5),
#  (248, 1, 'Yotpo', 65, 'Closed won', 'Commit', 366105, 33, datetime.datetime(2017, 7, 27, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 25, 0, 0), 4),
#  (249, 22, 'DST Global', 65, '(5) Negotiate & Close', 'Pipeline', 75032, 35, datetime.datetime(2017, 4, 10, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 10, 0, 0), 4),
#  (250, 1, 'Uber', 23, 'Closed Lost', 'Best Case', 276153, 15, datetime.datetime(2019, 12, 2, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 8, 22, 0, 0), 1),
#  (251, 26, 'Starling Bank', 44, 'Closed Lost', 'Commit', 371642, 27, datetime.datetime(2016, 12, 14, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 26, 0, 0), 1),
#  (252, 31, 'Binance', 75, '(4) Propose Solution', 'Pipeline', 141344, 28, datetime.datetime(2018, 9, 9, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 7, 11, 0, 0), 2),
#  (253, 1, 'Peloton', 45, '(2) Establish Needs', 'Pipeline', 298242, 22, datetime.datetime(2020, 2, 25, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 31, 0, 0), 3),
#  (254, 32, 'MessageBird', 9, '(1) Gain Access', 'Best Case', 247271, 27, datetime.datetime(2017, 4, 27, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 11, 0, 0), 5),
#  (255, 1, 'Sendbird', 17, '(3) Develop Solution', 'Best Case', 32628, 34, datetime.datetime(2019, 6, 13, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 7, 20, 0, 0), 2),
#  (256, 1, 'Uniphore', 6, '(2) Establish Needs', 'Commit', 12115, 18, datetime.datetime(2016, 10, 16, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 2, 0, 0), 2),
# ...
#  (912, 1, 'Workato', 97, '(2) Establish Needs', 'Pipeline', 147331, 16, datetime.datetime(2019, 3, 17, 0, 0), None, 'New Customer', datetime.datetime(2020, 11, 3, 0, 0), 1),
#  (913, 21, 'Afterpay', 40, '(3) Develop Solution', 'Commit', 327838, 29, datetime.datetime(2016, 10, 9, 0, 0), None, 'New Customer', datetime.datetime(2019, 4, 8, 0, 0), 3),
#  (914, 1, 'Pantera Capital', 13, '(4) Propose Solution', 'Pipeline', 75405, 23, datetime.datetime(2018, 5, 6, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 9, 0, 0), 1),
#  (915, 1, 'Armorblox', 31, '(1) Gain Access', 'Best Case', 143701, 27, datetime.datetime(2018, 8, 26, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 23, 0, 0), 1),
#  (916, 26, 'Capdesk', 4, 'Closed Lost', 'Commit', 199890, 15, datetime.datetime(2018, 7, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 11, 18, 0, 0), 2),
#  (917, 18, 'Pine Labs', 49, '(4) Propose Solution', 'Pipeline', 142086, 25, datetime.datetime(2018, 7, 5, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 6, 0, 0), 2),
#  (918, 1, 'OZY Media', 86, '(4) Propose Solution', 'Pipeline', 230450, 24, datetime.datetime(2019, 7, 17, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 12, 0, 0), 1),
#  (919, 1, 'Algolia', 75, '(2) Establish Needs', 'Pipeline', 85516, 12, datetime.datetime(2019, 2, 5, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 12, 0, 0), 1),
#  (920, 1, 'Mayvenn', 3, '(3) Develop Solution', 'Commit', 210934, 35, datetime.datetime(2016, 10, 31, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 1, 0, 0), 3),
#  (921, 1, 'Stash', 9, '(2) Establish Needs', 'Best Case', 194272, 21, datetime.datetime(2018, 9, 6, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 24, 0, 0), 6),
#  (922, 5, 'Snapcommerce', 78, 'Closed won', 'Pipeline', 154670, 13, datetime.datetime(2020, 1, 7, 0, 0), None, 'New Customer', datetime.datetime(2020, 6, 21, 0, 0), 2),
#  (923, 1, 'airSlate', 24, '(5) Negotiate & Close', 'Best Case', 395213, 32, datetime.datetime(2020, 10, 7, 0, 0), None, 'New Customer', datetime.datetime(2020, 6, 8, 0, 0), 3),
#  (924, 1, 'Remitly', 72, '(1) Gain Access', 'Best Case', 354464, 35, datetime.datetime(2018, 6, 29, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 6, 15, 0, 0), 5),
#  (925, 19, 'Xpeng Motors', 53, '(2) Establish Needs', 'Pipeline', 397794, 30, datetime.datetime(2017, 11, 27, 0, 0), None, 'New Customer', datetime.datetime(2020, 11, 27, 0, 0), 3),
#  (926, 26, 'Reef Finance', 51, '(4) Propose Solution', 'Best Case', 130970, 28, datetime.datetime(2016, 9, 30, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 18, 0, 0), 1),
#  (927, 26, 'Exscientia', 41, '(2) Establish Needs', 'Commit', 176918, 18, datetime.datetime(2019, 12, 19, 0, 0), None, 'New Customer', datetime.datetime(2020, 12, 26, 0, 0), 5),
#  (928, 1, 'Addition', 91, 'Closed won', 'Commit', 113836, 15, datetime.datetime(2016, 11, 30, 0, 0), 7, 'Existing Customer - Upsell', datetime.datetime(2020, 2, 23, 0, 0), 2),
#  (929, 1, 'Petco', 23, 'Closed Lost', 'Best Case', 355369, 15, datetime.datetime(2020, 11, 15, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 10, 26, 0, 0), 3),
#  (930, 30, 'Allianz', 93, '(1) Gain Access', 'Best Case', 154634, 21, datetime.datetime(2020, 3, 23, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 10, 0, 0), 6),
#  (931, 1, 'REEF Technology', 36, '(5) Negotiate & Close', 'Commit', 7779, 36, datetime.datetime(2017, 2, 25, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 9, 2, 0, 0), 6),
#  (932, 1, 'Blavity, Inc.', 80, '(2) Establish Needs', 'Best Case', 239060, 33, datetime.datetime(2017, 10, 4, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 3, 30, 0, 0), 2),
#  (933, 1, 'SmileDirectClub', 96, 'Closed Lost', 'Commit', 246677, 26, datetime.datetime(2019, 6, 7, 0, 0), None, 'New Customer', datetime.datetime(2019, 5, 8, 0, 0), 5),
#  (934, 52, 'Yandex', 16, '(3) Develop Solution', 'Commit', 319932, 13, datetime.datetime(2016, 8, 16, 0, 0), 16, 'Existing Customer - Upsell', datetime.datetime(2020, 8, 10, 0, 0), 1),
#  (935, 1, 'Kabbage', 54, '(5) Negotiate & Close', 'Commit', 77136, 35, datetime.datetime(2016, 6, 21, 0, 0), 25, 'Existing Customer - Upsell', datetime.datetime(2019, 5, 31, 0, 0), 4),
#  (936, 18, 'Snapdeal', 27, 'Closed Lost', 'Commit', 249706, 12, datetime.datetime(2018, 2, 14, 0, 0), 11, 'New Customer', datetime.datetime(2020, 11, 25, 0, 0), 4),
#  (937, 1, 'tray.io', 74, '(5) Negotiate & Close', 'Pipeline', 317180, 16, datetime.datetime(2016, 11, 12, 0, 0), 3, 'Existing Customer - Upsell', datetime.datetime(2020, 9, 9, 0, 0), 5),
#  (938, 1, 'Recursion Pharmaceuticals', 65, '(3) Develop Solution', 'Best Case', 6725, 12, datetime.datetime(2017, 4, 9, 0, 0), 15, 'Existing Customer - Upsell', datetime.datetime(2020, 11, 26, 0, 0), 6),
#  (939, 1, 'LaunchDarkly', 29, 'Closed Lost', 'Pipeline', 224769, 14, datetime.datetime(2018, 7, 29, 0, 0), 25, 'New Customer', datetime.datetime(2019, 8, 19, 0, 0), 1),
#  (940, 1, 'K2', 52, '(1) Gain Access', 'Commit', 310780, 19, datetime.datetime(2016, 1, 22, 0, 0), 10, 'New Customer', datetime.datetime(2019, 9, 8, 0, 0), 1),
#  (941, 7, 'Trafigura', 70, '(5) Negotiate & Close', 'Best Case', 205754, 19, datetime.datetime(2018, 10, 22, 0, 0), None, 'New Customer', datetime.datetime(2020, 5, 16, 0, 0), 1),
#  (942, 1, 'SingleStore', 73, '(3) Develop Solution', 'Best Case', 357721, 29, datetime.datetime(2016, 9, 16, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 4, 15, 0, 0), 4),
#  (943, 1, 'Zeni', 78, '(5) Negotiate & Close', 'Pipeline', 346358, 30, datetime.datetime(2019, 4, 23, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 4, 11, 0, 0), 6),
#  (944, 1, 'Farmers Business Network', 20, '(3) Develop Solution', 'Best Case', 75854, 13, datetime.datetime(2019, 3, 26, 0, 0), None, 'New Customer', datetime.datetime(2020, 6, 14, 0, 0), 2),
#  (945, 26, 'Barclays', 8, '(1) Gain Access', 'Commit', 326143, 14, datetime.datetime(2019, 2, 3, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 8, 18, 0, 0), 5),
#  (946, 1, 'Talkdesk', 10, '(4) Propose Solution', 'Best Case', 195967, 30, datetime.datetime(2020, 5, 16, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 27, 0, 0), 1),
#  (947, 32, 'EverBridge', 7, '(1) Gain Access', 'Commit', 377602, 19, datetime.datetime(2020, 10, 6, 0, 0), 3, 'New Customer', datetime.datetime(2020, 5, 20, 0, 0), 2),
#  (948, 1, 'Groupon', 14, '(3) Develop Solution', 'Pipeline', 190142, 23, datetime.datetime(2016, 9, 23, 0, 0), 22, 'New Customer', datetime.datetime(2020, 2, 9, 0, 0), 1),
#  (949, 5, 'Garage Capital', 61, 'Closed won', 'Commit', 270947, 26, datetime.datetime(2017, 4, 23, 0, 0), None, 'New Customer', datetime.datetime(2020, 4, 27, 0, 0), 1),
#  (950, 1, 'Ionis Pharmaceuticals', 58, '(5) Negotiate & Close', 'Commit', 271287, 21, datetime.datetime(2017, 1, 1, 0, 0), None, 'New Customer', datetime.datetime(2020, 12, 19, 0, 0), 6),
#  (951, 1, 'Rivery.io', 90, '(3) Develop Solution', 'Pipeline', 320855, 24, datetime.datetime(2019, 4, 23, 0, 0), 1, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 19, 0, 0), 6),
#  (952, 1, 'Quibi', 78, 'Closed won', 'Best Case', 167368, 16, datetime.datetime(2020, 7, 17, 0, 0), 5, 'New Customer', datetime.datetime(2020, 9, 27, 0, 0), 4),
#  (953, 1, 'Agilent Technologies', 14, 'Closed won', 'Best Case', 230676, 13, datetime.datetime(2016, 8, 28, 0, 0), 20, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 30, 0, 0), 2),
#  (954, 18, 'Wipro Technologies', 33, '(2) Establish Needs', 'Commit', 328327, 25, datetime.datetime(2016, 9, 10, 0, 0), 18, 'Existing Customer - Upsell', datetime.datetime(2019, 6, 15, 0, 0), 4),
#  (955, 1, 'Standard Cognition', 33, '(4) Propose Solution', 'Pipeline', 385655, 28, datetime.datetime(2019, 5, 9, 0, 0), 17, 'New Customer', datetime.datetime(2019, 5, 7, 0, 0), 3),
#  (956, 1, 'Goodr', 20, '(3) Develop Solution', 'Commit', 212891, 27, datetime.datetime(2017, 7, 13, 0, 0), 11, 'Existing Customer - Upsell', datetime.datetime(2019, 2, 10, 0, 0), 6),
#  (957, 1, 'Equinix', 89, '(1) Gain Access', 'Pipeline', 163790, 20, datetime.datetime(2019, 10, 21, 0, 0), 25, 'New Customer', datetime.datetime(2020, 4, 12, 0, 0), 3),
#  (958, 1, 'Cuyana', 23, '(1) Gain Access', 'Commit', 207293, 28, datetime.datetime(2018, 3, 31, 0, 0), 17, 'Existing Customer - Upsell', datetime.datetime(2019, 1, 5, 0, 0), 4),
#  (959, 1, 'Cynet', 72, '(3) Develop Solution', 'Commit', 325404, 23, datetime.datetime(2018, 12, 10, 0, 0), 9, 'New Customer', datetime.datetime(2020, 10, 25, 0, 0), 4),
#  (960, 18, 'Ecom Express', 48, '(1) Gain Access', 'Best Case', 150558, 23, datetime.datetime(2018, 2, 12, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 7, 27, 0, 0), 6),
#  (961, 26, 'MPB', 40, 'Closed Lost', 'Pipeline', 353966, 31, datetime.datetime(2020, 7, 15, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 6, 10, 0, 0), 3),
#  (962, 1, 'Puppet', 86, 'Closed Lost', 'Best Case', 45204, 27, datetime.datetime(2019, 6, 18, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 10, 0, 0), 3),
#  (963, 26, 'Codat', 41, 'Closed won', 'Best Case', 261609, 31, datetime.datetime(2019, 3, 16, 0, 0), None, 'New Customer', datetime.datetime(2019, 5, 26, 0, 0), 6),
#  (964, 18, 'Masai School', 56, '(3) Develop Solution', 'Best Case', 228898, 31, datetime.datetime(2016, 7, 13, 0, 0), None, 'New Customer', datetime.datetime(2020, 12, 15, 0, 0), 1),
#  (965, 52, 'Sberbank', 69, '(3) Develop Solution', 'Commit', 79620, 29, datetime.datetime(2016, 9, 22, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 10, 0, 0), 4),
#  (966, 26, 'Cazoo', 65, 'Closed Lost', 'Pipeline', 151355, 13, datetime.datetime(2020, 8, 5, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 9, 19, 0, 0), 6),
#  (967, 1, 'Aspiration', 48, '(5) Negotiate & Close', 'Best Case', 250936, 27, datetime.datetime(2018, 5, 19, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 27, 0, 0), 6),
#  (968, 7, 'Carousell', 18, 'Closed won', 'Pipeline', 142475, 32, datetime.datetime(2020, 10, 16, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 11, 17, 0, 0), 3),
#  (969, 1, 'Klaviyo', 31, 'Closed won', 'Best Case', 184059, 24, datetime.datetime(2017, 12, 2, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 10, 0, 0), 2),
#  (970, 1, 'General Assembly', 68, '(5) Negotiate & Close', 'Commit', 285111, 34, datetime.datetime(2016, 1, 5, 0, 0), None, 'New Customer', datetime.datetime(2019, 4, 21, 0, 0), 3),
#  (971, 26, 'Wellcome Trust', 47, '(4) Propose Solution', 'Best Case', 201690, 20, datetime.datetime(2019, 1, 1, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 11, 8, 0, 0), 5),
#  (972, 1, 'BitPay', 70, '(5) Negotiate & Close', 'Best Case', 154537, 29, datetime.datetime(2020, 6, 22, 0, 0), None, 'New Customer', datetime.datetime(2020, 2, 12, 0, 0), 3),
#  (973, 1, 'Dremio', 6, 'Closed won', 'Commit', 388263, 34, datetime.datetime(2019, 5, 24, 0, 0), None, 'New Customer', datetime.datetime(2019, 7, 4, 0, 0), 1),
#  (974, 1, 'Idelic', 66, '(3) Develop Solution', 'Commit', 198898, 22, datetime.datetime(2017, 11, 29, 0, 0), None, 'New Customer', datetime.datetime(2020, 3, 13, 0, 0), 1),
#  (975, 18, 'Upstox', 72, 'Closed Lost', 'Best Case', 91502, 25, datetime.datetime(2019, 8, 22, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 2, 18, 0, 0), 6),
#  (976, 19, 'Mask Network', 20, '(4) Propose Solution', 'Commit', 359335, 30, datetime.datetime(2017, 8, 25, 0, 0), None, 'New Customer', datetime.datetime(2020, 3, 14, 0, 0), 5),
#  (977, 1, 'Bowery Farming', 97, '(1) Gain Access', 'Commit', 325258, 14, datetime.datetime(2018, 12, 5, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 25, 0, 0), 3),
#  (978, 1, 'KeepTruckin', 49, 'Closed won', 'Commit', 234035, 24, datetime.datetime(2017, 3, 20, 0, 0), None, 'New Customer', datetime.datetime(2020, 7, 27, 0, 0), 6),
#  (979, 1, 'Care.com', 30, '(5) Negotiate & Close', 'Best Case', 293921, 13, datetime.datetime(2017, 10, 3, 0, 0), None, 'New Customer', datetime.datetime(2019, 8, 7, 0, 0), 6),
#  (980, 26, 'GlaxoSmithKline', 86, '(3) Develop Solution', 'Best Case', 335756, 25, datetime.datetime(2019, 2, 22, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 5, 7, 0, 0), 5),
#  (981, 1, 'Fundbox', 59, 'Closed won', 'Commit', 248202, 13, datetime.datetime(2020, 3, 15, 0, 0), None, 'New Customer', datetime.datetime(2019, 5, 6, 0, 0), 5),
#  (982, 1, 'Mission Barns', 11, 'Closed won', 'Pipeline', 88668, 21, datetime.datetime(2019, 6, 23, 0, 0), 20, 'Existing Customer - Upsell', datetime.datetime(2020, 10, 11, 0, 0), 2),
#  (983, 1, 'Colgate Palmolive', 20, 'Closed Lost', 'Pipeline', 19955, 14, datetime.datetime(2019, 8, 2, 0, 0), 10, 'New Customer', datetime.datetime(2020, 6, 7, 0, 0), 6),
#  (984, 5, 'Hootsuite', 57, '(1) Gain Access', 'Best Case', 371672, 24, datetime.datetime(2017, 6, 7, 0, 0), 5, 'New Customer', datetime.datetime(2020, 2, 25, 0, 0), 2),
#  (985, 1, 'Aura Financial', 39, '(5) Negotiate & Close', 'Best Case', 310531, 21, datetime.datetime(2017, 2, 23, 0, 0), 12, 'New Customer', datetime.datetime(2020, 11, 30, 0, 0), 2),
#  (986, 1, 'Alkami Technology', 71, '(3) Develop Solution', 'Pipeline', 366991, 29, datetime.datetime(2020, 10, 10, 0, 0), 12, 'Existing Customer - Upsell', datetime.datetime(2019, 7, 11, 0, 0), 1),
#  (987, 1, 'Metromile', 66, '(5) Negotiate & Close', 'Pipeline', 166194, 32, datetime.datetime(2020, 3, 15, 0, 0), None, 'New Customer', datetime.datetime(2019, 10, 1, 0, 0), 1),
#  (988, 1, '3DLOOK', 69, 'Closed won', 'Commit', 359911, 21, datetime.datetime(2020, 8, 8, 0, 0), None, 'New Customer', datetime.datetime(2019, 2, 1, 0, 0), 3),
#  (989, 1, 'AvidXchange', 12, '(1) Gain Access', 'Commit', 270250, 18, datetime.datetime(2018, 1, 31, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 4, 3, 0, 0), 5),
#  (990, 26, 'Gyroscope Therapeutics', 3, 'Closed won', 'Commit', 269338, 21, datetime.datetime(2018, 7, 10, 0, 0), None, 'New Customer', datetime.datetime(2020, 1, 31, 0, 0), 3),
#  (991, 18, 'UpGrad', 68, 'Closed Lost', 'Pipeline', 208669, 14, datetime.datetime(2018, 11, 5, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 11, 0, 0), 1),
#  (992, 1, 'Olive', 31, '(5) Negotiate & Close', 'Commit', 155303, 23, datetime.datetime(2018, 4, 19, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 4, 17, 0, 0), 5),
#  (993, 1, 'Augmedics', 59, '(4) Propose Solution', 'Best Case', 184823, 23, datetime.datetime(2017, 4, 12, 0, 0), None, 'New Customer', datetime.datetime(2020, 10, 15, 0, 0), 5),
#  (994, 1, 'Infor', 82, '(4) Propose Solution', 'Best Case', 52544, 13, datetime.datetime(2020, 7, 4, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 12, 25, 0, 0), 6),
#  (995, 1, 'Edmunds', 49, '(4) Propose Solution', 'Best Case', 204385, 17, datetime.datetime(2019, 9, 11, 0, 0), None, 'New Customer', datetime.datetime(2019, 9, 27, 0, 0), 2),
#  (996, 1, 'Eventbrite', 55, '(5) Negotiate & Close', 'Pipeline', 133517, 21, datetime.datetime(2017, 1, 8, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 3, 16, 0, 0), 2),
#  (997, 1, 'appfire', 82, '(1) Gain Access', 'Best Case', 265043, 18, datetime.datetime(2020, 1, 2, 0, 0), None, 'New Customer', datetime.datetime(2019, 12, 11, 0, 0), 5),
#  (998, 1, 'Magic', 77, '(3) Develop Solution', 'Commit', 9803, 35, datetime.datetime(2019, 9, 13, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 5, 11, 0, 0), 2),
#  (999, 19, 'Weibo', 65, '(1) Gain Access', 'Pipeline', 246959, 16, datetime.datetime(2019, 4, 15, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2020, 1, 20, 0, 0), 2),
#  (1000, 1, 'Alyce', 41, '(3) Develop Solution', 'Commit', 397710, 26, datetime.datetime(2019, 8, 1, 0, 0), None, 'Existing Customer - Upsell', datetime.datetime(2019, 11, 8, 0, 0), 6),
#  ...]

# %% [markdown]
#    Through the above queries we were able to find out that a total of 3305 records do not have a PartnerId. To further the exploration, I also generated a query to list all the accounts that do not have a ParnterId and then queried the entire table just to get a better idea of how this data is laid out. Based on my exploration, customer accounts that have been generated in-house are not tied to a partner which is represented by the NULL value. On the other hand, customer accounts that are coming through partner channels are tied to a PartnerId which links into the partner the Partners table where we can see the name of the partner tied to a specific account. In the future it may be better to explicitly document that there is no partner attached to an account. As the NULL value is a little ambiguous and it could be hard to tell if a customer account does not have an account or the record was entered incorrectly.
#
#    This information can be useful as we can now compare how many of the company's sales and potential sales were/are being done through a partner vs their own resources. We can also compare the contract price to see if the company makes a larger sale through its partners or on its own. Analysis can also be done to see who the top selling partners are, and what regions working with a partner has been the most affective.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# b). Another area worth exploring is the contract price. In order to get an idea of how much the company sells its products and services for and to look for any outliers (which could artificially raise or drop the average contract price) we can run standard descriptive measures

# %%
# %%sql
# SELECT
#     COUNT(ContractPrice) AS 'N',
#     SUM(ContractPrice) AS 'sum',
#     AVG(ContractPrice) AS 'mean',
#     STDDEV(ContractPrice) AS 'std. dev.',
#     VAR_POP(ContractPrice) AS 'varience',
#     MIN(ContractPrice) AS 'min',
#     MAX(ContractPrice) AS 'max'
# FROM Accounts;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(4112, Decimal('790360865'), Decimal('192208.3816'), 116420.47704666048, 13553727475.772001, 1724, 399713)]

# %% [markdown]
# Through the above descriptive statistics of the contract price, we find:
#
# * The total number of rows in the accounts table is 4,112
# * Total dollar amount of contracts both in the pipe and closed is 790,360,865
# * Average price of a contract from this company is 192,208.38
# * A high standard deviation of 116,420.48 and an extremely high variance of 13,553,727,475.77
# * The smallest contract was priced at 1,724
# * Largest contract was priced at 399,713
#
# The large standard deviation indicates that the contract prices are spread across a large range of values and do not hover around the mean. In addition, the variance not only confirms the wide range of values from the mean, but also shows us that the contract prices in relation to each other are very different. Based on the variance and standard deviation we can tell that there is little to no correlation between the contract prices. Although these values make sense for this specific dataset for this project since the data was randomly generated, it does not accurately represent what one would find in a live sales dataset professionally. Companies usually have set pricing based on what product or service they are buying. Therefore, we would expect larger similarity between the contract prices and the standard deviation and variance to be way smaller.
#
# Conducting descriptive statistics is helpful not just for sales analyst, but any analyst that is working with a new dataset and is trying to get a better understanding of it. Descriptive statistics provide a great baseline for analyst to build their understanding and analysis on.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# c). Now that we have a better understanding of what the NULL values mean for PartnerId and have a better picture of the price data points, let’s explore what countries the company sells to.

# %%
# %%sql
# SELECT
#     CountryName,
#     RegionName
# FROM Countries c
# JOIN CountryRegions cr
#     ON c.CountryId = cr.CountryId
# JOIN Regions r
#     ON cr.RegionID = r.RegionID;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 70 rows affected.
# [('United States', 'AMER'),
#  ('Canada', 'AMER'),
#  ('Mexico', 'LATAM'),
#  ('Chile', 'LATAM'),
#  ('Peru', 'LATAM'),
#  ('Colombia', 'LATAM'),
#  ('Dominica', 'LATAM'),
#  ('Costa Rica', 'LATAM'),
#  ('Guatemala', 'LATAM'),
#  ('Brazil', 'LATAM'),
#  ('Haiti', 'LATAM'),
#  ('Saint Lucia', 'LATAM'),
#  ('Uruguay', 'LATAM'),
#  ('Cayman Islands', 'LATAM'),
#  ('Argentina', 'LATAM'),
#  ('Philippines', 'APAC'),
#  ('New Zealand', 'APAC'),
#  ('Singapore', 'APAC'),
#  ('Vietnam', 'APAC'),
#  ('Thailand', 'APAC'),
#  ('Malaysia', 'APAC'),
#  ('Fiji', 'APAC'),
#  ('India', 'APAC'),
#  ('China', 'APAC'),
#  ('Australia', 'APAC'),
#  ('Hong Kong', 'APAC'),
#  ('South Korea', 'APAC'),
#  ('Taiwan', 'APAC'),
#  ('Indonesia', 'APAC'),
#  ('Poland', 'APAC'),
#  ('Lithuania', 'APAC'),
#  ('Bermuda', 'APAC'),
#  ('Romania', 'APAC'),
#  ('Croatia', 'APAC'),
#  ('Belgium', 'APAC'),
#  ('Latvia', 'APAC'),
#  ('Pakistan', 'APAC'),
#  ('Greece', 'APAC'),
#  ('Portugal', 'APAC'),
#  ('Bangladesh', 'APAC'),
#  ('Hungary', 'APAC'),
#  ('Iceland', 'APAC'),
#  ('Jordan', 'APAC'),
#  ('Saudi Arabia', 'APAC'),
#  ('Lebanon', 'APAC'),
#  ('Japan', 'JPN'),
#  ('United Kingdom', 'EMEA'),
#  ('Sweden', 'EMEA'),
#  ('Finland', 'EMEA'),
#  ('Israel', 'EMEA'),
#  ('Germany', 'EMEA'),
#  ('Malta', 'EMEA'),
#  ('The Netherlands', 'EMEA'),
#  ('Denmark', 'EMEA'),
#  ('France', 'EMEA'),
#  ('Switzerland', 'EMEA'),
#  ('Estonia', 'EMEA'),
#  ('Azerbaijan', 'EMEA'),
#  ('Ireland', 'EMEA'),
#  ('Spain', 'EMEA'),
#  ('Italy', 'EMEA'),
#  ('Ukraine', 'EMEA'),
#  ('Norway', 'EMEA'),
#  ('Austria', 'EMEA'),
#  ('Turkey', 'EMEA'),
#  ('Bahrain', 'EMEA'),
#  ('United Arab Emirates', 'EMEA'),
#  ('Russian Federation', 'EMEA'),
#  ('Czech Republic', 'EMEA'),
#  ('Slovenia', 'EMEA')]

# %%
# %%sql
# SELECT
#     RegionName,
#     COUNT(CountryId) AS count_countries
# FROM Regions r
# JOIN CountryRegions cr
#     ON r.RegionId = cr.RegionId
# GROUP BY RegionName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('AMER', 2), ('LATAM', 13), ('APAC', 30), ('JPN', 1), ('EMEA', 24)]

# %% [markdown]
# Based on the above queries we now know that the company sells its products and/or services in 70 different countries located in different parts of the global. The second SQL query illustrates what regions each of the countries reside in. According to the output we see that the company has closed and potential sales in:
#
# * 2 countries in North America (AMEA)
# * 13 countries in South/Latin America (LATAM)
# * 30 countries in Asia and the Asia Pacific (APAC)
# * 24 countries in Europe (EMEA)
# * Japan (JPN which has recently been moved to its own region)
#
# Knowing this information can be helpful as we can do a regional sales analysis to see where the company is performing well versus not so well. In addition, we can also break it down even further to examine each individual country within a given region to pinpoint exactly where the company is or is not selling. This can ultimately lead to improving marketing efforts in the underperforming area, team up with a local partner, change up the product or service offered in the country or region, or the company can decide that it is not worth trying to sell in that location anymore.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# d). Next I will run some Max() and Min() on the ContractStartDate, CloseDate, and ContractLenghtMonths column to get an idea of the date range for this dataset. This will help determine how old these accounts are and provide insight on how long the typical contract term is for a customer.

# %%
# %%sql
# SELECT
#     MAX(LEFT(ContractStartDate,4)) AS max_year_contract_start,
#     MIN(LEFT(ContractStartDate,4)) AS min_year_contract_start,
#     MAX(LEFT(CloseDate, 4)) AS max_year_contract_close,
#     MIN(LEFT(CloseDate, 4)) AS min_year_contract_close
# FROM Accounts;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [('2020', '2016', '2020', '2019')]

# %%
# %%sql
# SELECT
#     MAX(ContractLengthMonths) AS max_contract_length_months,
#     MIN(ContractLengthMonths) AS min_contract_length_months,
#     AVG(ContractLengthMonths) AS avg_contract_length_months
# FROM Accounts;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 1 rows affected.
# [(60, 5, Decimal('23.8176'))]

# %% [markdown]
# After looking at the above SQL queries we find that the expected and/or actual contract start dates range anywhere from 2016 to 2020. However, none of these contracts were closed before 2019 as seen through the min_year_contract_close column in the first query. This provides an inconsistency within the data especially for the contracts with an expected start date ranging from 2016-2018. Since none of these contracts were closed before 2019, that would render any of the start dates before 2019 as invalid since the sale was not complete. Now the contract start dates could have been the estimated start dates, but then the deal failed to close as projected.
#
# As for the query done for the contract length in months, we find out that the largest contract the company has or is expected to have is 60 months (roughly 5 years) while the smallest contract they have or are expected to have is only 5 months. We also find that the average sales contract at this company tends to last 23.8 months or 1.98 years. With this information we see that the company tends to prefer short-term contracts with their longest one lasting roughly 5 years.
#
# Typically, when doing analysis, dates will play a very important role. In the context of sales data, you could use dates to compare quarters both from a realized sales perspective as well as from a pipeline projection perspective. You could also drill down even more by looking at your sales monthly to pinpoint where the sales peaks and troughs are. The sales data can also be looked at from the fiscal calendar or from the yearly calendar point of view as well.
#
# Since the start and closed dates for this dataset are not consistent, we will just have to assume that the ContractStartDate column represents the expected start date of the contract and the same for the ClosedDate. In the future it may be helpful to beak this information up into two different columns. For example, one column would represent the expected start and closed date while the other would represent the actual start and closed date.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# e). The final part of exploration will be focused on examining the data that surrounds the company's sales reps.

# %%
# %%sql
# SELECT *
# FROM SalesReps;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 7 rows affected.
# [(1, 'Robert', 'Smith'),
#  (2, 'Jose', 'Gomez'),
#  (3, 'Rachel', 'King'),
#  (4, 'Bobby', 'Thompson'),
#  (5, 'Michelle', 'Clarence'),
#  (6, 'Katie', 'Barmen'),
#  (7, 'Tony', 'Stamp')]

# %%
# %%sql
# SELECT
#     EmployeeFirstName,
#     EmployeeLastName,
#     COUNT(a.EmployeeId) AS number_of_contracts
# FROM SalesReps sr
# JOIN Accounts a
#     ON sr.EmployeeId = a.EmployeeId
# GROUP BY EmployeeFirstName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 7 rows affected.
# [('Robert', 'Smith', 691),
#  ('Jose', 'Gomez', 658),
#  ('Rachel', 'King', 654),
#  ('Bobby', 'Thompson', 700),
#  ('Michelle', 'Clarence', 703),
#  ('Katie', 'Barmen', 705),
#  ('Tony', 'Stamp', 1)]

# %%
# %%sql
# SELECT
#     DISTINCT EmployeeFirstName,
#     EmployeeLastName,
#     RegionName,
#     COUNT(r.RegionId) OVER (
#         PARTITION BY RegionName, a.EmployeeId
#     ) AS number_accounts_in_region
# FROM SalesReps sr
# JOIN Accounts a
#     ON sr.EmployeeId = a.EmployeeId
# JOIN Countries c
#     ON a.CountryId = c.CountryId
# JOIN CountryRegions cr
#     ON c.CountryId = cr.CountryId
# JOIN Regions r
#     ON cr.RegionId = r.RegionId
# ORDER BY EmployeeFirstName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 31 rows affected.
# [('Bobby', 'Thompson', 'LATAM', 9),
#  ('Bobby', 'Thompson', 'AMER', 472),
#  ('Bobby', 'Thompson', 'JPN', 9),
#  ('Bobby', 'Thompson', 'APAC', 100),
#  ('Bobby', 'Thompson', 'EMEA', 110),
#  ('Jose', 'Gomez', 'AMER', 459),
#  ('Jose', 'Gomez', 'LATAM', 7),
#  ('Jose', 'Gomez', 'APAC', 88),
#  ('Jose', 'Gomez', 'JPN', 9),
#  ('Jose', 'Gomez', 'EMEA', 95),
#  ('Katie', 'Barmen', 'LATAM', 9),
#  ('Katie', 'Barmen', 'JPN', 5),
#  ('Katie', 'Barmen', 'EMEA', 104),
#  ('Katie', 'Barmen', 'APAC', 130),
#  ('Katie', 'Barmen', 'AMER', 457),
#  ('Michelle', 'Clarence', 'EMEA', 115),
#  ('Michelle', 'Clarence', 'APAC', 79),
#  ('Michelle', 'Clarence', 'LATAM', 30),
#  ('Michelle', 'Clarence', 'JPN', 4),
#  ('Michelle', 'Clarence', 'AMER', 475),
#  ('Rachel', 'King', 'EMEA', 95),
#  ('Rachel', 'King', 'APAC', 71),
#  ('Rachel', 'King', 'JPN', 3),
#  ('Rachel', 'King', 'AMER', 477),
#  ('Rachel', 'King', 'LATAM', 8),
#  ('Robert', 'Smith', 'APAC', 82),
#  ('Robert', 'Smith', 'AMER', 474),
#  ('Robert', 'Smith', 'LATAM', 8),
#  ('Robert', 'Smith', 'EMEA', 120),
#  ('Robert', 'Smith', 'JPN', 7),
#  ('Tony', 'Stamp', 'APAC', 1)]

# %% [markdown]
# For the first query I did a select * statement on the sales reps table just to see what kind of data we had strictly surrounding the sales reps. After running this query, we find that there is not a whole lot of information. The company only has 7 sales reps, and the only information we have surrounding these reps include an EmployeeId and their first and last name. In the furture it could be helpful to have more information such as their hire date, work email, and/or a work phone number.
#
# Now that I know what data we have surrounding the company's sales reps, I wanted to see how many accounts each rep has tied to them. After running the second query we find that:
#
# * Robert Smith has 691 contracts
# * Jose Gomez has 658 contracts
# * Rachel King has 654 contracts
# * Bobby Thompson has 700 contracts
# * Michelle Clarence has 703 contracts
# * Katie Barmen has 705 contracts
# * Tony Stamp has 1 contract
#
# It is important to note that the count includes both open and closed contracts, comparing the number of open versus closed contracts per rep is something I plan on looking at in part 2 of my analysis. With this information we can get a basic idea of which sales rep have to most customer accounts. It is interesting that Tony Stamp only has 1 contract, it could be because the rep is an under performer, or it this rep may just be a new employee and has not had as long of a chance to sell like his colleagues have (therefore a hired date would have been helpful).
#
# Finally, I wanted to break up the number of contracts per rep by region to see which region each rep was most active in. For all of the reps the North American (AMER) region seems to be where they are establishing most of their sales contracts with Europe (EMEA) coming in at a very distant second. Square which is the company that posted the job description I am basing this analysis off, is a U.S. based company. So, it would make sense that most sales for this dataset would be skewed towards AMER. In addition, it would also appear that all reps have a global presence. Normally sales reps would be assigned to sell in a specific region, however, to keep the data unbiased during the data collection phase, I randomly assigned reps to the companies I pulled from the CrunchBase API.
#
# Overall, keeping track of sales rep performance is important to track the team's progress and success by looking at how much each representative has sold (which is what I plan to do in part two of my analysis). In addition, this information can also help the compensation team as SDR’s, and AE's make the bulk of their compensation through variable. Collecting this information can help them document and better understand the variable size that each employee should get. In addition, it is also a good way to keep track of high performers and reward them for their hard work by giving special rewards like getting invited to a "Club" event.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# ## Part 2: Answering Business Questions with Data

# %% [markdown]
# ##### Question 1:
# For the year 2020, where we able to achieve our sales forecasts for each region? If not, how far under the forecast where we?
#
# ##### Business Justification:
# Comparing your forecasted sales with your realized sales provides the sales team with feedback on how their performance was for the year. If the team was able to hit or exceed their forecasted sales number, then the sales team can re-adjust next year's forecast to be higher. On the flip side, if the team did not hit their forecasted numbers, they can also lower their forecasted numbers to offer a more attainable goal. The unclosed business (if it is not closed lost) could also be carried over to next year's forecasts thus improving the chances that the sales team will achieve their goals. This query mainly works to provide the sales executives insight into what their sales team is capable of and that they are hitting their revenue targets
#
# ##### SQL Features Used:
# * CTE
# * INNER JOIN
# * GROUP BY

# %%
# %%sql
# WITH sales_forecast_cte AS (
#     SELECT
#         RegionName,
#         SUM(ContractPrice) AS forecast_sales
#     FROM Accounts a
#     JOIN CountryRegions cr
#         ON a.CountryId = cr.CountryId
#     JOIN Regions r
#         ON cr.RegionId = r.RegionID
#     WHERE ForecastCategory IN ('Pipeline', 'Best Case', 'Commit')
#         AND ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:23:59'
#     GROUP BY RegionName
# ),
# realized_sales_cte AS (
#     SELECT
#         RegionName,
#         SUM(ContractPrice) AS realized_sales
#  FROM Accounts a
#     JOIN CountryRegions cr
#         ON a.CountryId = cr.CountryId
#     JOIN Regions r
#         ON cr.RegionId = r.RegionID
#     WHERE SalesStage = 'Closed Won'
#         AND ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:23:59'
#     GROUP BY RegionName
# )
# SELECT
#     sf.RegionName,
#     forecast_sales,
#     realized_sales,
#     realized_sales > forecast_sales AS over_forecast,
#     forecast_sales - realized_sales AS amount_under
# FROM sales_forecast_cte sf
# JOIN realized_sales_cte rs
#     ON sf.RegionName = rs.RegionName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('AMER', Decimal('113688411'), Decimal('16034600'), 0, Decimal('97653811')),
#  ('APAC', Decimal('18434031'), Decimal('2574884'), 0, Decimal('15859147')),
#  ('EMEA', Decimal('26633185'), Decimal('2471762'), 0, Decimal('24161423')),
#  ('LATAM', Decimal('2102126'), Decimal('347328'), 0, Decimal('1754798')),
#  ('JPN', Decimal('981569'), Decimal('191793'), 0, Decimal('789776'))]

# %% [markdown]
# Through these results, we find that for the calendar year 2020 the sales team was able to hit their forecasted sales numbers for each of the regions. If I was a sales leader, the first thing I would do is debrief with each of my sales reps to get an idea of what next year's forecast looks like and how many of the deals that were not closed do they expect to close in the following year. Then I would readjust next year’s forecasts to be smaller and more realistic to the amount of revenue the company can generate. Based on the amount_under column it is obvious that the sales team greatly overestimated how much they could sell in a year. All the regions except for Japan under sold their forecasts by millions of dollars. Japan was only under the forecast by 789,776, but that is still an extreme misestimation by the sales team considering that JPN only represents Japan. I would suggest that the sales team re-adjust their forecast to be more reflective of how much sales the company can currently generate. Setting ridiculously high forecasts and sales targets is a good way to set the company up for failure, and destroy team moral.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# ##### Question 2:
# Let’s drill down and look at which individual regions, partners, and sales reps performed the best in terms of sales revenue generated. In addition, how did each of our partners stack up against the dollar amount of sales closed in-house without any partner support?
#
# ##### Business Justification:
# By breaking down which regions are doing well by realized sales dollars, the company get a clear picture of what regions are troublesome for making sales. For example, the company can look at the lower ranked regions and do an analysis of why they are struggling to sell in those regions. It could be a culture miss match with the product or marketing strategy, high local competition, or maybe the product and/or service is just not needed in those locations.
#
# It is also beneficial to look at partner performance because a bad partner could prolong or even kill a deal. The company is also paying these partners a percentage based off the size of the deal, so there really is no need to keep on dead weight and waste costs. In addition, comparing the dollar amount of sales brought in without a partner versus with a partner is a good way to ensure that most deals are coming through the company itself and not outside partners. More revenue can be generated through in-house sales as there are no extra costs associated with them.
#
# Finally, it is also a good idea to keep track of your sales rep’s performance not only to generate healthy competition, but also to ensure that the employees are being rewarded appropriately for work they have put in to close deals. It can be a big morale booster when your top sales reps get rewarded with bonuses and invited to company "club" events. In addition, having these numbers handy can help sort out how much commission an employee should be or was paid for a given year.
#
# ##### SQL Features Used:
# * Window Function - DENSE_RANK() & COUNT()
# * LEFT & INNER JOIN
# * GROUP BY
# * Subquery
# * VIEW

# %%
# %%sql
# SELECT
#     RegionName,
#     SUM(ContractPrice) AS realized_sales,
#     DENSE_RANK() OVER (
#         ORDER BY SUM(ContractPrice) DESC
#     ) AS region_rank_by_sales
# FROM Accounts a
# JOIN CountryRegions cr
#     ON a.CountryId = cr.CountryId
# JOIN Regions r
#     ON cr.RegionId = r.RegionId
# WHERE SalesStage = 'Closed Won'
#     AND ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
# GROUP BY RegionName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('AMER', Decimal('16034600'), 1),
#  ('APAC', Decimal('2574884'), 2),
#  ('EMEA', Decimal('2471762'), 3),
#  ('LATAM', Decimal('347328'), 4),
#  ('JPN', Decimal('191793'), 5)]

# %%
# %%sql
# SELECT
#     PartnerName,
#     SUM(ContractPrice) AS realized_sales,
#     (
#         SELECT SUM(ContractPrice)
#         FROM Accounts a
#         LEFT JOIN Partners p
#             ON a.PartnerId = p.PartnerId
#         WHERE PartnerName IS NULL
#             AND ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#             AND SalesStage = 'Closed Won'
#     ) - SUM(ContractPrice) AS amount_below_nonpartner_sales,
#     RANK() OVER (
#         ORDER BY SUM(ContractPrice) DESC
#     ) AS partner_rank_by_sales
# FROM Accounts a
# LEFT JOIN Partners p
#     ON a.PartnerId = p.PartnerId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#     AND SalesStage = 'Closed Won'
# GROUP BY PartnerName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 20 rows affected.
# [(None, Decimal('15787910'), Decimal('0'), 1),
#  ('Tech Mahindra Limited India', Decimal('608584'), Decimal('15179326'), 2),
#  ('VietSoftware international Inc.', Decimal('492892'), Decimal('15295018'), 3),
#  ('Impulse IT Ltda.', Decimal('458895'), Decimal('15329015'), 4),
#  ('Ricksoft Co., Ltd', Decimal('384503'), Decimal('15403407'), 5),
#  ('Crest Infosolutions SDN BHD', Decimal('369392'), Decimal('15418518'), 6),
#  ('Carahsoft Technology Corporation', Decimal('350965'), Decimal('15436945'), 7),
#  ('Cognizant Technology Solutions Corporation', Decimal('349577'), Decimal('15438333'), 8),
#  ('Infomega SAS', Decimal('337593'), Decimal('15450317'), 9),
#  ('CROZ d.o.o. (SI)', Decimal('331515'), Decimal('15456395'), 10),
#  ('ClearCadence, LLC', Decimal('321652'), Decimal('15466258'), 11),
#  ('Tata Consultancy Services Limited - India', Decimal('303153'), Decimal('15484757'), 12),
#  ('Technology Services Group', Decimal('261575'), Decimal('15526335'), 13),
#  ('iik Technologies - Desarrollo de Soluciones de Software SA de CV', Decimal('258719'), Decimal('15529191'), 14),
#  ('APIUX Technologia SPA.', Decimal('243048'), Decimal('15544862'), 15),
#  ('Armedia LLC', Decimal('239108'), Decimal('15548802'), 16),
#  ('Crest Business Solutions Pte Ltd', Decimal('196697'), Decimal('15591213'), 17),
#  ('Amihan\xa0Global\xa0Strategies\xa0Phils\xa0Inc', Decimal('122874'), Decimal('15665036'), 18),
#  ('Global Quark S.A. de C.V.', Decimal('113000'), Decimal('15674910'), 19),
#  ('Contezza BV', Decimal('88715'), Decimal('15699195'), 20)]

# %%
# %%sql
# SELECT
#     PartnerName,
#     SUM(ContractPrice) AS realized_sales,
#     RANK() OVER (
#         ORDER BY SUM(ContractPrice) DESC
#     ) AS partner_rank_by_sales
# FROM Accounts a
# JOIN Partners p
#     ON a.PartnerId = p.PartnerId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#     AND SalesStage = 'Closed Won'
# GROUP BY PartnerName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 19 rows affected.
# [('Tech Mahindra Limited India', Decimal('608584'), 1),
#  ('VietSoftware international Inc.', Decimal('492892'), 2),
#  ('Impulse IT Ltda.', Decimal('458895'), 3),
#  ('Ricksoft Co., Ltd', Decimal('384503'), 4),
#  ('Crest Infosolutions SDN BHD', Decimal('369392'), 5),
#  ('Carahsoft Technology Corporation', Decimal('350965'), 6),
#  ('Cognizant Technology Solutions Corporation', Decimal('349577'), 7),
#  ('Infomega SAS', Decimal('337593'), 8),
#  ('CROZ d.o.o. (SI)', Decimal('331515'), 9),
#  ('ClearCadence, LLC', Decimal('321652'), 10),
#  ('Tata Consultancy Services Limited - India', Decimal('303153'), 11),
#  ('Technology Services Group', Decimal('261575'), 12),
#  ('iik Technologies - Desarrollo de Soluciones de Software SA de CV', Decimal('258719'), 13),
#  ('APIUX Technologia SPA.', Decimal('243048'), 14),
#  ('Armedia LLC', Decimal('239108'), 15),
#  ('Crest Business Solutions Pte Ltd', Decimal('196697'), 16),
#  ('Amihan\xa0Global\xa0Strategies\xa0Phils\xa0Inc', Decimal('122874'), 17),
#  ('Global Quark S.A. de C.V.', Decimal('113000'), 18),
#  ('Contezza BV', Decimal('88715'), 19)]

# %%
# %%sql
# SELECT
#     EmployeeFirstName,
#     EmployeeLastName,
#     SUM(ContractPrice) AS realized_sales,
#     RANK() OVER (
#         ORDER BY SUM(ContractPrice) DESC
#     ) AS sales_rep_rank_by_sales
# FROM SalesReps sr
# LEFT JOIN Accounts a
#     ON sr.EmployeeId = a.EmployeeId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31'
#     AND SalesStage = 'Closed Won'
# GROUP BY EmployeeFirstName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 6 rows affected.
# [('Robert', 'Smith', Decimal('4974747'), 1),
#  ('Katie', 'Barmen', Decimal('4524231'), 2),
#  ('Rachel', 'King', Decimal('3979588'), 3),
#  ('Jose', 'Gomez', Decimal('3903490'), 4),
#  ('Michelle', 'Clarence', Decimal('2422192'), 5),
#  ('Bobby', 'Thompson', Decimal('1816119'), 6)]

# %%
# %%sql
# CREATE OR REPLACE VIEW sales_breakdown_by_rep_region AS
# SELECT
#     DISTINCT sr.EmployeeId,
#     EmployeeFirstName,
#     EmployeeLastName,
#     RegionName,
#     SUM(ContractPrice) OVER (
#         PARTITION BY RegionName, a.EmployeeId
#     ) AS realized_sales_per_region_per_rep
# FROM SalesReps sr
# JOIN Accounts a
#     ON sr.EmployeeId = a.EmployeeId
# JOIN Countries c
#     ON a.CountryId = c.CountryId
# JOIN CountryRegions cr
#     ON c.CountryId = cr.CountryId
# JOIN Regions r
#     ON cr.RegionId = r.RegionId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#     AND SalesStage = 'Closed Won'
# Order BY EmployeeFirstName;
#
# SELECT
#     DISTINCT EmployeeFirstName,
#     EmployeeLastName,
#     RegionName,
#     realized_sales_per_region_per_rep,
#     COUNT(AccountId) OVER (
#         PARTITION BY RegionName, a.EmployeeId
#     ) AS number_of_accounts_in_region
# FROM sales_breakdown_by_rep_region sbrr
# JOIN Accounts a
#     ON sbrr.EmployeeId = a.EmployeeId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59';
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 0 rows affected.
# 23 rows affected.
# [('Robert', 'Smith', 'AMER', Decimal('3638263'), 148),
#  ('Jose', 'Gomez', 'AMER', Decimal('2668125'), 160),
#  ('Rachel', 'King', 'AMER', Decimal('3515853'), 131),
#  ('Bobby', 'Thompson', 'AMER', Decimal('1149983'), 127),
#  ('Michelle', 'Clarence', 'AMER', Decimal('1840349'), 133),
#  ('Katie', 'Barmen', 'AMER', Decimal('3222027'), 133),
#  ('Robert', 'Smith', 'APAC', Decimal('556786'), 148),
#  ('Jose', 'Gomez', 'APAC', Decimal('727805'), 160),
#  ('Rachel', 'King', 'APAC', Decimal('367307'), 131),
#  ('Bobby', 'Thompson', 'APAC', Decimal('530566'), 127),
#  ('Michelle', 'Clarence', 'APAC', Decimal('204645'), 133),
#  ('Katie', 'Barmen', 'APAC', Decimal('187775'), 133),
#  ('Robert', 'Smith', 'EMEA', Decimal('682809'), 148),
#  ('Jose', 'Gomez', 'EMEA', Decimal('507560'), 160),
#  ('Rachel', 'King', 'EMEA', Decimal('32981'), 131),
#  ('Bobby', 'Thompson', 'EMEA', Decimal('110408'), 127),
#  ('Michelle', 'Clarence', 'EMEA', Decimal('377198'), 133),
#  ('Katie', 'Barmen', 'EMEA', Decimal('760806'), 133),
#  ('Robert', 'Smith', 'JPN', Decimal('96889'), 148),
#  ('Katie', 'Barmen', 'JPN', Decimal('94904'), 133),
#  ('Rachel', 'King', 'LATAM', Decimal('63447'), 131),
#  ('Bobby', 'Thompson', 'LATAM', Decimal('25162'), 127),
#  ('Katie', 'Barmen', 'LATAM', Decimal('258719'), 133)]

# %% [markdown]
# The first query looks at the top regions in terms of realized sales dollars for the year 2019. After query the results we find that:
# * AMER is number one with 16,034,600
# * APAC is number two with 2,574,884
# * EMEA is number three with 2,471,762
# * JPN is number four with 347,328
# * LATAM is number five with 191,793
#
# My suggestion would be to focus a lot of the attention on the region JPN and LATAM as those sales numbers for 2019 are drastically lower than EMEA, APAC, and AMER. I would start by looking at the sales strategy and marketing strategies in those regions. If the strategies check out, then it may be time to think about not selling so much those regions and just focus on increasing sales in EMEA and APAC to try and close the gap with the AMER region.
#
# The next two queries provide a breakdown of partner performance. The first query compares how much (in terms of dollars) each of the company's partners sold in 2020 versus the company itself. The company itself is represented by None which is at the top of the list. It is good that the company is ranked number one on the list because that means that most sales are coming from in-house efforts. The second query is just a ranked list showing who the best and worst partners are for the year 2020. My only suggestion here would be for the company to potentially re-evaluate the partnership between the bottom five partners. I chose the bottom five partners because the biggest drop in terms of sales dollars occurs after Armedia LLC at 239,108. The bottom four partner companies come in at 196,697 (Crest Business Solutions Pte Ltd), 122,874 (Amihan Global Strategies Phils Inc), 113,000 (Global Quark S.A. de C.V.), and 88,715 (Contezza BV).
#
# The fourth query just shows who the top sales performers were for the year 2020. My recommendation here would be to look at the bottom performers Bobby Thompson and Michelle Clarence and potentially put them through more sales training. I would also recommend rewarding Robert Smith accordingly as he was last year’s top performer and the company's number one revenue generator by roughly 450K+ for the year.
#
# The third query then breaks down each sales rep's performance in each region. Based on the generated list, all the reps except for Robert Smith and Katie Barmen were having trouble selling in Japan in 2020. In addition, Jose Gomez, Robert Smith, and Michelle Clarence did not have any LATAM sales in 2020. We also find that Tony Stamp did not sell anything in 2020. In addition, we see how many accounts each rep was working in 2020, and it seems hefty. My recommendation would be to hire more sales reps, as each rep is working 100+ accounts in almost every region putting a lot of stress on the team. The high workload may be why many sales reps did not make it to LATAM and JPN in 2020.

# %% [markdown]
# <center>-----------------------------------------------------------------------------------------------------------------------------------------------------</center>

# %% [markdown]
# ##### Question 3:
#  Now we know who top performers are in terms of realized sales dollar generation, but let’s compare last years closed won deals with closed lost deals. In which regions did we lose the most sales, and which sales reps are struggling to close deals? Provide a list of the customers we lost that year as well.
#
# ##### Business Justification:
# Comparing closed won and lost deals helps the company gauge the effectiveness of their sales strategy. In addition, by looking at the accounts lost it provides the sales and marketing teams an opportunity to learn from their mistakes and refine their tactics and approaches. Looking at the closed lost deals also allows the company to look at where exactly in the process they lost the potential customer, and what tactic or feature did the competitor use to pull the customer over to their product instead of ours.
#
# ##### SQL Features Used:
# * CTE
# * INNER & LEFT JOIN
# * CASE
# * GROUP BY

# %%
# %%sql
# WITH lost_rep_deals AS (
#     SELECT
#         EmployeeFirstName,
#         EmployeeLastName,
#         COUNT(AccountId) AS number_lost_accounts,
#         SUM(ContractPrice) AS closed_lost_sales
#     FROM Accounts a
#     JOIN SalesReps sr
#         ON a.EmployeeId = sr.EmployeeId
#     WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#         AND SalesStage = 'Closed Lost'
#     GROUP BY EmployeeFirstName
#     ORDER BY closed_lost_sales DESC
# ),
# won_rep_deals AS (
#     SELECT
#         EmployeeFirstName,
#         EmployeeLastName,
#         COUNT(AccountId) AS number_won_accounts,
#         SUM(ContractPrice) AS closed_won_sales
#     FROM Accounts a
#     JOIN SalesReps sr
#         ON a.EmployeeId = sr.EmployeeId
#     WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#         AND SalesStage = 'Closed Won'
#     GROUP BY EmployeeFirstName
#     ORDER BY closed_won_sales DESC
# )
# SELECT
#     lrd.EmployeeFirstName,
#     lrd.EmployeeLastName,
#     number_lost_accounts,
#     closed_lost_sales,
#     number_won_accounts,
#     closed_won_sales,
#     CASE
#         WHEN closed_lost_sales > closed_won_sales THEN '-'
#         ELSE '+'
#     END AS loss_vs_won_sales_status
# FROM lost_rep_deals lrd
# JOIN won_rep_deals wrd
#     ON lrd.EmployeeFirstName = wrd.EmployeeFirstName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 6 rows affected.
# [('Robert', 'Smith', 26, Decimal('5487813'), 23, Decimal('4974747'), '-'),
#  ('Jose', 'Gomez', 19, Decimal('3788830'), 19, Decimal('3903490'), '+'),
#  ('Bobby', 'Thompson', 16, Decimal('3522794'), 14, Decimal('1816119'), '-'),
#  ('Rachel', 'King', 18, Decimal('3422597'), 20, Decimal('3979588'), '+'),
#  ('Michelle', 'Clarence', 13, Decimal('2833347'), 17, Decimal('2422192'), '-'),
#  ('Katie', 'Barmen', 13, Decimal('2048624'), 23, Decimal('4524231'), '+')]

# %%
# %%sql
#
# WITH lost_region_deals AS (
#     SELECT
#         RegionName,
#         COUNT(AccountId) AS number_lost_accounts,
#         SUM(ContractPrice) AS closed_lost_sales
#     FROM Accounts a
#     JOIN CountryRegions cr
#         ON a.CountryId = cr.CountryId
#     JOIN Regions r
#         ON cr.RegionId = r.RegionId
#     WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#         AND SalesStage = 'Closed Lost'
#     GROUP BY RegionName
#     ORDER BY closed_lost_sales DESC
# ),
# won_region_deals AS (
#     SELECT
#         RegionName,
#         COUNT(AccountId) AS number_won_accounts,
#         SUM(ContractPrice) AS closed_won_sales
#     FROM Accounts a
#     JOIN CountryRegions cr
#         ON a.CountryId = cr.CountryId
#     JOIN Regions r
#         ON cr.RegionId = r.RegionId
#     WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#         AND SalesStage = 'Closed Won'
#     GROUP BY RegionName
#     ORDER BY closed_won_sales DESC
# )
# SELECT
#     wrd.RegionName,
#     number_lost_accounts,
#     closed_lost_sales,
#     number_won_accounts,
#     closed_won_sales,
#     CASE
#         WHEN closed_lost_sales > closed_won_sales THEN '-'
#         ELSE '+'
#     END AS loss_vs_won_sales_status
# FROM won_region_deals wrd
# LEFT JOIN lost_region_deals lrd
#     ON lrd.RegionName = wrd.RegionName;
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 5 rows affected.
# [('AMER', 75, Decimal('14116893'), 84, Decimal('16034600'), '+'),
#  ('APAC', 11, Decimal('2557464'), 14, Decimal('2574884'), '+'),
#  ('EMEA', 19, Decimal('4429648'), 13, Decimal('2471762'), '-'),
#  ('LATAM', None, None, 3, Decimal('347328'), '+'),
#  ('JPN', None, None, 2, Decimal('191793'), '+')]

# %%
# %%sql
# SELECT
#     RegionName,
#     AccountName,
#     SalesStage
# FROM Accounts a
# JOIN CountryRegions cr
#     ON a.CountryId = cr.CountryId
# JOIN Regions r
#     ON cr.RegionId = r.RegionId
# WHERE ContractStartDate BETWEEN '2020-1-1' AND '2020-12-31 23:59:59'
#     AND SalesStage = 'Closed Lost'
# Out:
#  * mysql://admin:***@lmu-dev-01.ch3fswgxeqfe.us-east-1.rds.amazonaws.com/sql_project
# 105 rows affected.
# [('AMER', 'Calendly', 'Closed Lost'),
#  ('APAC', 'Paytm', 'Closed Lost'),
#  ('AMER', 'QuantumScape', 'Closed Lost'),
#  ('AMER', 'Payoneer', 'Closed Lost'),
#  ('EMEA', 'Camunda', 'Closed Lost'),
#  ('AMER', 'Signal', 'Closed Lost'),
#  ('EMEA', 'Siemens', 'Closed Lost'),
#  ('EMEA', 'what3words', 'Closed Lost'),
#  ('AMER', 'Axis Security', 'Closed Lost'),
#  ('AMER', 'Aeva', 'Closed Lost'),
#  ('APAC', 'Big Hit Entertainment', 'Closed Lost'),
#  ('APAC', 'CICC', 'Closed Lost'),
#  ('AMER', 'Vimeo', 'Closed Lost'),
#  ('APAC', 'Info Edge', 'Closed Lost'),
#  ('AMER', 'Via', 'Closed Lost'),
#  ('AMER', 'Superhuman', 'Closed Lost'),
#  ('AMER', 'Petco', 'Closed Lost'),
#  ('EMEA', 'MPB', 'Closed Lost'),
#  ('EMEA', 'Cazoo', 'Closed Lost'),
#  ('AMER', 'PICKUP', 'Closed Lost'),
#  ('AMER', 'Alt', 'Closed Lost'),
#  ('AMER', 'Kaiser Permanente', 'Closed Lost'),
#  ('AMER', 'Tetrate', 'Closed Lost'),
#  ('AMER', 'Saks Fifth Avenue', 'Closed Lost'),
#  ('EMEA', 'Skeleton Technologies', 'Closed Lost'),
#  ('AMER', 'Riskified', 'Closed Lost'),
#  ('AMER', 'PandaDoc', 'Closed Lost'),
#  ('EMEA', 'Mirakl', 'Closed Lost'),
#  ('EMEA', 'GetYourGuide', 'Closed Lost'),
#  ('APAC', 'Ather Energy', 'Closed Lost'),
#  ('AMER', 'Second Closet', 'Closed Lost'),
#  ('AMER', 'Veritas Capital', 'Closed Lost'),
#  ('AMER', 'CircleCI', 'Closed Lost'),
#  ('AMER', 'Eden Health', 'Closed Lost'),
#  ('EMEA', 'Genesis Global', 'Closed Lost'),
#  ('AMER', '100Plus', 'Closed Lost'),
#  ('AMER', 'HomeLight', 'Closed Lost'),
#  ('APAC', 'FloBiz', 'Closed Lost'),
#  ('AMER', 'GoodRx', 'Closed Lost'),
#  ('EMEA', 'Cellink', 'Closed Lost'),
#  ('AMER', 'Beam Therapeutics', 'Closed Lost'),
#  ('AMER', 'Endless West', 'Closed Lost'),
#  ('AMER', 'FreightWaves', 'Closed Lost'),
#  ('EMEA', 'Decibel', 'Closed Lost'),
#  ('EMEA', 'Debenhams', 'Closed Lost'),
#  ('AMER', 'Mason', 'Closed Lost'),
#  ('AMER', 'CareDx', 'Closed Lost'),
#  ('AMER', 'Heal', 'Closed Lost'),
#  ('AMER', 'Jetty', 'Closed Lost'),
#  ('AMER', 'Biz2Credit', 'Closed Lost'),
#  ('AMER', 'Simple Health', 'Closed Lost'),
#  ('AMER', 'Click Therapeutics', 'Closed Lost'),
#  ('AMER', 'Swyft', 'Closed Lost'),
#  ('EMEA', 'Abzu', 'Closed Lost'),
#  ('AMER', 'GrowGeneration', 'Closed Lost'),
#  ('AMER', 'AgBiome', 'Closed Lost'),
#  ('AMER', 'FreshDirect', 'Closed Lost'),
#  ('AMER', 'SparkPost', 'Closed Lost'),
#  ('AMER', 'Fivestars', 'Closed Lost'),
#  ('APAC', 'Nreal', 'Closed Lost'),
#  ('AMER', 'Stocktwits', 'Closed Lost'),
#  ('APAC', 'Kyber Network', 'Closed Lost'),
#  ('AMER', 'Clever', 'Closed Lost'),
#  ('AMER', 'JUUL', 'Closed Lost'),
#  ('AMER', 'QVC', 'Closed Lost'),
#  ('AMER', 'PicsArt', 'Closed Lost'),
#  ('AMER', 'Capchase', 'Closed Lost'),
#  ('AMER', 'Listo', 'Closed Lost'),
#  ('AMER', 'Mammoth Biosciences', 'Closed Lost'),
#  ('AMER', 'Ladder', 'Closed Lost'),
#  ('AMER', 'HoneyBook', 'Closed Lost'),
#  ('AMER', 'Rebag', 'Closed Lost'),
#  ('AMER', 'OpenWeb', 'Closed Lost'),
#  ('APAC', 'Trell', 'Closed Lost'),
#  ('AMER', 'Woflow', 'Closed Lost'),
#  ('AMER', 'TrustRadius', 'Closed Lost'),
#  ('EMEA', 'TradingView', 'Closed Lost'),
#  ('EMEA', 'Maze', 'Closed Lost'),
#  ('AMER', 'Digbi Health', 'Closed Lost'),
#  ('AMER', 'DrChrono', 'Closed Lost'),
#  ('AMER', 'Enigma Technologies', 'Closed Lost'),
#  ('AMER', 'Token Transit', 'Closed Lost'),
#  ('AMER', 'Earnest', 'Closed Lost'),
#  ('EMEA', 'Splyt', 'Closed Lost'),
#  ('AMER', 'LambdaTest', 'Closed Lost'),
#  ('AMER', 'Zeus Living', 'Closed Lost'),
#  ('AMER', 'Framework Ventures', 'Closed Lost'),
#  ('AMER', 'Descartes Labs', 'Closed Lost'),
#  ('AMER', 'RumbleON', 'Closed Lost'),
#  ('AMER', 'Embark', 'Closed Lost'),
#  ('EMEA', 'Signal AI', 'Closed Lost'),
#  ('AMER', 'Boston Dynamics', 'Closed Lost'),
#  ('AMER', 'Nature’s Fynd', 'Closed Lost'),
#  ('AMER', 'Fauna', 'Closed Lost'),
#  ('AMER', 'FreeWheel', 'Closed Lost'),
#  ('AMER', 'L7 Informatics', 'Closed Lost'),
#  ('APAC', 'GetWork', 'Closed Lost'),
#  ('EMEA', 'StorageOS', 'Closed Lost'),
#  ('AMER', 'TriNet', 'Closed Lost'),
#  ('AMER', 'Quicklly', 'Closed Lost'),
#  ('AMER', 'Simplilearn', 'Closed Lost'),
#  ('AMER', 'Kenna Security', 'Closed Lost'),
#  ('EMEA', 'CybelAngel', 'Closed Lost'),
#  ('AMER', 'HVR', 'Closed Lost'),
#  ('APAC', 'Future Retail', 'Closed Lost')]

# %% [markdown]
# In a nutshell the first two queries outline the number of accounts lost/won and the dollar amount of lost/won accounts both by sales rep and region. In addition, for both queries I added a CASE statement to indicate whether the dollar amount of lost sales is larger than the dollar amount of won sales for the year 2020. a '+' means that the dollar amount of closed won deals is greater than the dollar amount of closed lost deals and the '-' means the opposite.
#
# We see that Katie Barmen, Rachel King, and Jose Gomez all have realized sales for 2020 greater than the dollar amount they lost. On the other hand, Robert Smith, Bobby Thompson, and Michelle Smith all lost more sales dollars than they gained. In addition, we also see that the only region that was not profitable for the company in 2020 was EMEA.
#
# The third query is just a list of customers who decided not to buy the company's product.
#
# Ultimately my recommendation would be for the sales executives to debrief with all their reps starting with the ones that closed the year at a loss. Have them discuss what is and is not working in terms of sales tactics and/or product pricing and positioning. I would also suggest that the company re-evaluate the EMEA market to see why the region was not profitable in 2020. Also, if possible I would also recommend that the sales team look back at the phone recordings for the lost customers and review the notes in SFDC to try and pinpoint exactly where they lost the customer in the process.
